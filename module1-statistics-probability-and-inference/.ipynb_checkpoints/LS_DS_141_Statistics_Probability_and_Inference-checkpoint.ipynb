# %% [markdown]
# # Lambda School Data Science Module 141
# ## Statistics, Probability, and Inference

# %% [markdown]
# ## Prepare - examine what's available in SciPy
#
# As we delve into statistics, we'll be using more libraries - in particular the [stats package from SciPy](https://docs.scipy.org/doc/scipy/reference/tutorial/stats.html).

# %%
from scipy import stats
import matplotlib.pyplot as plt

# %%
# As usual, lots of stuff here! There's our friend, the normal distribution
norm = stats.norm()
print(norm.mean())
print(norm.std())
print(norm.var())
# Out:
# 0.0
# 1.0
# 1.0

# %%
# And a new friend - t
t1 = stats.t(5)  # 5 is df "shape" parameter
print(t1.mean())
print(t1.std())
print(t1.var())
# Out:
# 0.0
# 1.2909944487358056
# 1.6666666666666667

# %% [markdown]
# ![T distribution PDF with different shape parameters](https://upload.wikimedia.org/wikipedia/commons/4/41/Student_t_pdf.svg)
#
# *(Picture from [Wikipedia](https://en.wikipedia.org/wiki/Student's_t-distribution#/media/File:Student_t_pdf.svg))*
#
# The t-distribution is "normal-ish" - the larger the parameter (which reflects its degrees of freedom - more input data/features will increase it), the closer to true normal.

# %%
t2 = stats.t(30)  # Will be closer to normal
print(t2.mean())
print(t2.std())
print(t2.var())
# Out:
# 0.0
# 1.0350983390135313
# 1.0714285714285714

# %% [markdown]
# Why is it different from normal? To better reflect the tendencies of small data and situations with unknown population standard deviation. In other words, the normal distribution is still the nice pure ideal in the limit (thanks to the central limit theorem), but the t-distribution is much more useful in many real-world situations.
#
# History sidenote - this is "Student":
#
# ![William Sealy Gosset](https://upload.wikimedia.org/wikipedia/commons/4/42/William_Sealy_Gosset.jpg)
#
# *(Picture from [Wikipedia](https://en.wikipedia.org/wiki/File:William_Sealy_Gosset.jpg))*
#
# His real name is William Sealy Gosset, and he published under the pen name "Student" because he was not an academic. He was a brewer, working at Guinness and using trial and error to determine the best ways to yield barley. He's also proof that, even 100 years ago, you don't need official credentials to do real data science!

# %% [markdown]
# ## Live Lecture - let's perform and interpret a t-test
#
# We'll generate our own data, so we can know and alter the "ground truth" that the t-test should find. We will learn about p-values and how to interpret "statistical significance" based on the output of a hypothesis test.

# %% [markdown]
# ## Assignment - apply the t-test to real data
#
# Your assignment is to determine which issues have "statistically significant" differences between political parties in this [1980s congressional voting data](https://archive.ics.uci.edu/ml/datasets/Congressional+Voting+Records). The data consists of 435 instances (one for each congressperson), a class (democrat or republican), and 16 binary attributes (yes or no for voting for or against certain issues). Be aware - there are missing values!
#
# Your goals:
#
# 1. Load and clean the data (or determine the best method to drop observations when running tests)
# 2. Using hypothesis testing, find an issue that democrats support more than republicans with p < 0.01
# 3. Using hypothesis testing, find an issue that republicans support more than democrats with p < 0.01
# 4. Using hypothesis testing, find an issue where the difference between republicans and democrats has p > 0.1 (i.e. there may not be much of a difference)
#
# Note that this data will involve *2 sample* t-tests, because you're comparing averages across two groups (republicans and democrats) rather than a single group against a null hypothesis.
#
# Stretch goals:
#
# 1. Refactor your code into functions so it's easy to rerun with arbitrary variables
# 2. Apply hypothesis testing to your personal project data (for the purposes of this notebook you can type a summary of the hypothesis you formed and tested)

# %%
pd.options.display.float_format = '{:,.10f}'.format

# %%
titles = ""\
 + "handicapped-infants "\
 + "water-project-cost-sharing "\
 + "adoption-of-the-budget-resolution "\
 + "physician-fee-freeze el-salvador-aid "\
 + "religious-groups-in-schools "\
 + "anti-satellite-test-ban "\
 + "aid-to-nicaraguan-contras "\
 + "mx-missile immigration "\
 + "synfuels-corporation-cutback "\
 + "education-spending "\
 + "superfund-right-to-sue "\
 + "crime "\
 + "duty-free-exports "\
 + "export-administration-act-south-africa"

issues = titles.replace("-", "_").split(" ")

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/voting-records/house-votes-84.data"
raw_votes = pd\
    .read_csv(url, header=None)\
    .rename(columns={0: 'affiliation'})\
    .rename(columns={k:v for k,v in list(zip(range(1,len(issues)+1), issues))})\
    .set_index('affiliation')

# %%
votes = raw_votes.replace({'?': 0, 'n': 0, 'y': 1})

# %%
import scipy as s

def student_t(df):
    def dist(t):
        numer = s.special.gamma((df+1)/2)
        denom = np.sqrt(np.pi*df)*s.special.gamma(df/2)
        scale = np.power((1+(np.power(t,2)/df)),-((df+1)/2))
        return (numer/denom)*scale
    return dist
    
def one_sided_t_test(sample, population):
    numer = sample.mean() - population.mean()
    denom = sample.std()/np.sqrt(sample.size)
    return numer/denom

def two_sided_t_test(sample_1, sample_2):
    numer = sample_1.mean() - sample_2.mean()
    denom = np.sqrt((np.power(sample_1.std(),2)/sample_1.size) + (np.power(sample_2.std(),2)/sample_2.size))
    return numer/denom

# %%
approx = pd.DataFrame()

for party in ['democrat', 'republican']:
    for issue in issues:
        population = votes[issue]
        sample = votes.loc[party, issue]
        
        df = sample.size
        st = student_t(df-1)
        
        t_test_1 = one_sided_t_test(sample, population)
        t_test_2 = two_sided_t_test(sample, population)
        pvalue_1 = st(t_test_1)
        pvalue_2 = st(t_test_2)
        
        approx.loc[issue, party+'_one_sided_t_test'] = t_test_1
        approx.loc[issue, party+'_one_sided_p_value'] = pvalue_1
        approx.loc[issue, party+'_two_sided_t_test'] = t_test_2
        approx.loc[issue, party+'_two_sided_p_value'] = pvalue_2

approx
# Out:
#                                         democrat_one_sided_t_test  \
# handicapped_infants                                  5.1089574226
# water_project_cost_sharing                           0.0381097447
# adoption_of_the_budget_resolution                   13.5406278523
# physician_fee_freeze                               -25.9356777232
# el_salvador_aid                                    -11.3467384580
# religious_groups_in_schools                         -5.3862056706
# anti_satellite_test_ban                              7.5100654900
# aid_to_nicaraguan_contras                           10.9613045996
# mx_missile                                           8.1561499342
# immigration                                         -1.0507861385
# synfuels_corporation_cutback                         4.5143777098
# education_spending                                 -12.3330969115
# superfund_right_to_sue                              -7.5764930569
# ...

# %%
voting_scores = pd.DataFrame()

for party in ['democrat', 'republican']:
    for issue in issues:
        population = votes[issue]
        sample = votes.loc[party, issue]
        
        student_t_1samp = s.stats.ttest_1samp(sample, population.mean())
        student_t_ind = s.stats.ttest_ind(sample, population, equal_var=False)

        voting_scores.loc[issue, party+'_one_sided_t_test'] = student_t_1samp.statistic
        voting_scores.loc[issue, party+'_one_sided_p_value'] = student_t_1samp.pvalue
        voting_scores.loc[issue, party+'_two_sided_t_test'] = student_t_ind.statistic
        voting_scores.loc[issue, party+'_two_sided_p_value'] = student_t_ind.pvalue

voting_scores
# Out:
#                                         democrat_one_sided_t_test  \
# handicapped_infants                                  5.1089574226
# water_project_cost_sharing                           0.0381097447
# adoption_of_the_budget_resolution                   13.5406278523
# physician_fee_freeze                               -25.9356777232
# el_salvador_aid                                    -11.3467384580
# religious_groups_in_schools                         -5.3862056706
# anti_satellite_test_ban                              7.5100654900
# aid_to_nicaraguan_contras                           10.9613045996
# mx_missile                                           8.1561499342
# immigration                                         -1.0507861385
# synfuels_corporation_cutback                         4.5143777098
# education_spending                                 -12.3330969115
# superfund_right_to_sue                              -7.5764930569
# ...

# %%
compared_scores = pd.DataFrame()

for issue in issues:
    democrats = votes.loc['democrat', issue]
    republicans = votes.loc['republican', issue]

    student_t_ind = s.stats.ttest_ind(democrats, republicans, nan_policy='omit', equal_var=False)

    compared_scores.loc[issue, 't_test'] = student_t_ind.statistic
    compared_scores.loc[issue, 'p_value'] = student_t_ind.pvalue

compared_scores
# Out:
#                                            t_test        p_value
# handicapped_infants                      9.385156   4.310985e-19
# water_project_cost_sharing               0.061305   9.511504e-01
# adoption_of_the_budget_resolution       21.938891   3.207052e-68
# physician_fee_freeze                   -48.392868  3.235499e-173
# el_salvador_aid                        -23.256810   3.265911e-78
# religious_groups_in_schools            -10.880232   1.548410e-24
# anti_satellite_test_ban                 12.272816   3.476462e-29
# aid_to_nicaraguan_contras               18.707842   7.279839e-56
# mx_missile                              15.887749   4.995543e-45
# immigration                             -1.691790   9.156290e-02
# synfuels_corporation_cutback             8.971270   9.012007e-18
# education_spending                     -17.977679   3.083774e-50
# superfund_right_to_sue                 -13.118390   8.728913e-33
# ...

# %%
threshold = 0.01

# %%
# bills which democrats are more likely to support than republicans
is_significant = compared_scores['p_value'] < threshold
is_relevant = 0 < compared_scores['t_test']

compared_scores[is_significant & is_relevant].index.values
# Out:
# array(['handicapped_infants', 'adoption_of_the_budget_resolution',
#        'anti_satellite_test_ban', 'aid_to_nicaraguan_contras',
#        'mx_missile', 'synfuels_corporation_cutback', 'duty_free_exports'], dtype=object)

# %%
# bills which democrats are more likely to support than republicans
is_significant = compared_scores['p_value'] < threshold
is_relevant = compared_scores['t_test'] < 0

compared_scores[is_significant & is_relevant].index.values
# Out:
# array(['physician_fee_freeze', 'el_salvador_aid',
#        'religious_groups_in_schools', 'education_spending',
#        'superfund_right_to_sue', 'crime'], dtype=object)

# %%
# Using hypothesis testing, find an issue where the difference between republicans and democrats has p > 0.1
threshold = 0.1

is_significant = compared_scores['p_value'] > threshold

compared_scores[is_significant].index.values
# Out:
# array(['water_project_cost_sharing',
#        'export_administration_act_south_africa'], dtype=object)
