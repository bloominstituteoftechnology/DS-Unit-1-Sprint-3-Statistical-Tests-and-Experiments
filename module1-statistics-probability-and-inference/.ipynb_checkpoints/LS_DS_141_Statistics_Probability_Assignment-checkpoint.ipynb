# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 1 Sprint 3 Assignment 1*
#
# # Apply the t-test to real data
#
# Your assignment is to determine which issues have "statistically significant" differences between political parties in this [1980s congressional voting data](https://archive.ics.uci.edu/ml/datasets/Congressional+Voting+Records). The data consists of 435 instances (one for each congressperson), a class (democrat or republican), and 16 binary attributes (yes or no for voting for or against certain issues). Be aware - there are missing values!
#
# Your goals:
#
# 1. Load and clean the data (or determine the best method to drop observations when running tests)
# 2. Using hypothesis testing, find an issue that democrats support more than republicans with p < 0.01
# 3. Using hypothesis testing, find an issue that republicans support more than democrats with p < 0.01
# 4. Using hypothesis testing, find an issue where the difference between republicans and democrats has p > 0.1 (i.e. there may not be much of a difference)
#
# Note that this data will involve *2 sample* t-tests, because you're comparing averages across two groups (republicans and democrats) rather than a single group against a null hypothesis.
#
# Stretch goals:
#
# 1. Refactor your code into functions so it's easy to rerun with arbitrary variables
# 2. Apply hypothesis testing to your personal project data (for the purposes of this notebook you can type a summary of the hypothesis you formed and tested)

# %%
### YOUR CODE STARTS HERE

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import ttest_ind, ttest_ind_from_stats, ttest_rel
import re

# %%
features = '''
1. Class Name: 2 (democrat, republican) 
2. handicapped-infants: 2 (y,n) 
3. water-project-cost-sharing: 2 (y,n) 
4. adoption-of-the-budget-resolution: 2 (y,n) 
5. physician-fee-freeze: 2 (y,n) 
6. el-salvador-aid: 2 (y,n) 
7. religious-groups-in-schools: 2 (y,n) 
8. anti-satellite-test-ban: 2 (y,n) 
9. aid-to-nicaraguan-contras: 2 (y,n) 
10. mx-missile: 2 (y,n) 
11. immigration: 2 (y,n) 
12. synfuels-corporation-cutback: 2 (y,n) 
13. education-spending: 2 (y,n) 
14. superfund-right-to-sue: 2 (y,n) 
15. crime: 2 (y,n) 
16. duty-free-exports: 2 (y,n) 
17. export-administration-act-south-africa: 2 (y,n)
'''
features = re.findall(r'\d+?. (.+?):',features)

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/voting-records/house-votes-84.data', names=features)
df = df.replace({'?': np.nan, 'n': 0, 'y': 1})
df.tail(10)
# Out:
#      Class Name  handicapped-infants  water-project-cost-sharing  \
# 425    democrat                  0.0                         0.0
# 426    democrat                  1.0                         0.0
# 427  republican                  0.0                         0.0
# 428    democrat                  NaN                         NaN
# 429    democrat                  1.0                         0.0
# 430  republican                  0.0                         0.0
# 431    democrat                  0.0                         0.0
# 432  republican                  0.0                         NaN
# 433  republican                  0.0                         0.0
# 434  republican                  0.0                         1.0
#
#      adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 425                                1.0                   0.0              0.0
# 426                                1.0                   0.0              0.0
# ...

# %%
def make_conclusion(feature,df,alpha=0.01):
    classes = ['Republicans', 'Democrats']
    republican = df[df['Class Name']=='republican'][feature]
    democrat = df[df['Class Name']=='democrat'][feature]
    republican = republican.dropna()
    democrat = democrat.dropna()
    more_supporting = classes[int(republican.mean() < democrat.mean())]
    #print(republican.mean(), democrat.mean())
    less_supporting = classes[republican.mean() > democrat.mean()]
    p_val = ttest_ind(republican, democrat).pvalue
    
    if(p_val<alpha):
        result = 'The %s supports the issue of %s more than the %s (%.4f<%.2f)' %\
            (more_supporting, feature, less_supporting,p_val,alpha)
    else:
        result = 'There is not a statistically significant difference between the '\
            'Republicans and the Democrats with regards to support on %s (%.4f>%.2f)' % \
            (feature,p_val,alpha)
    
    return result

# %%
for feature in features[1:]:
    print(make_conclusion(feature,df, 0.01))
    print('----')
# Out:
# The Democrats supports the issue of handicapped-infants more than the Republicans (0.0000<0.01)
# ----
# There is not a statistically significant difference between the Republicans and the Democrats with regards to support on water-project-cost-sharing (0.9292>0.01)
# ----
# The Democrats supports the issue of adoption-of-the-budget-resolution more than the Republicans (0.0000<0.01)
# ----
# The Republicans supports the issue of physician-fee-freeze more than the Democrats (0.0000<0.01)
# ----
# The Republicans supports the issue of el-salvador-aid more than the Democrats (0.0000<0.01)
# ----
# The Republicans supports the issue of religious-groups-in-schools more than the Democrats (0.0000<0.01)
# ----
# The Democrats supports the issue of anti-satellite-test-ban more than the Republicans (0.0000<0.01)
# ----
# The Democrats supports the issue of aid-to-nicaraguan-contras more than the Republicans (0.0000<0.01)
# ----
# ...
