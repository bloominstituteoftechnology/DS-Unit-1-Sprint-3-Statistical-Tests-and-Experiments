# %% [markdown]
# # Lambda School Data Science Module 142
# ## Sampling, Confidence Intervals, and Hypothesis Testing

# %% [markdown]
# ## Prepare - examine other available hypothesis tests
#
# If you had to pick a single hypothesis test in your toolbox, t-test would probably be the best choice - but the good news is you don't have to pick just one! Here's some of the others to be aware of:

# %%
import numpy as np
from scipy.stats import chisquare  # One-way chi square test

# Chi square can take any crosstab/table and test the independence of rows/cols
# The null hypothesis is that the rows/cols are independent -> low chi square
# The alternative is that there is a dependence -> high chi square
# Be aware! Chi square does *not* tell you direction/causation

ind_obs = np.array([[1, 1], [2, 2]]).T
print(ind_obs)
print(chisquare(ind_obs, axis=None))

dep_obs = np.array([[16, 18, 16, 14, 12, 12], [32, 24, 16, 28, 20, 24]]).T
print(dep_obs)
print(chisquare(dep_obs, axis=None))
# Out:
# [[1 2]
#  [1 2]]
# Power_divergenceResult(statistic=0.6666666666666666, pvalue=0.8810148425137847)
# [[16 32]
#  [18 24]
#  [16 16]
#  [14 28]
#  [12 20]
#  [12 24]]
# Power_divergenceResult(statistic=23.31034482758621, pvalue=0.015975692534127565)

# %%
# Distribution tests:
# We often assume that something is normal, but it can be important to *check*

# For example, later on with predictive modeling, a typical assumption is that
# residuals (prediction errors) are normal - checking is a good diagnostic

from scipy.stats import normaltest
# Poisson models arrival times and is related to the binomial (coinflip)
sample = np.random.poisson(5, 1000)
print(normaltest(sample))  # Pretty clearly not normal
# Out:
# NormaltestResult(statistic=38.69323106073592, pvalue=3.961609200867749e-09)

# %%
# Kruskal-Wallis H-test - compare the median rank between 2+ groups
# Can be applied to ranking decisions/outcomes/recommendations
# The underlying math comes from chi-square distribution, and is best for n>5
from scipy.stats import kruskal

x1 = [1, 3, 5, 7, 9]
y1 = [2, 4, 6, 8, 10]
print(kruskal(x1, y1))  # x1 is a little better, but not "significantly" so

x2 = [1, 1, 1]
y2 = [2, 2, 2]
z = [2, 2]  # Hey, a third group, and of different size!
print(kruskal(x2, y2, z))  # x clearly dominates
# Out:
# KruskalResult(statistic=0.2727272727272734, pvalue=0.6015081344405895)
# KruskalResult(statistic=7.0, pvalue=0.0301973834223185)

# %% [markdown]
# And there's many more! `scipy.stats` is fairly comprehensive, though there are even more available if you delve into the extended world of statistics packages. As tests get increasingly obscure and specialized, the importance of knowing them by heart becomes small - but being able to look them up and figure them out when they *are* relevant is still important.

# %% [markdown]
# ## Live Lecture - let's explore some more of scipy.stats

# %%
# Taking requests! Come to lecture with a topic or problem and we'll try it.

# %% [markdown]
# ## Assignment - Build a confidence interval
#
# A confidence interval refers to a neighborhood around some point estimate, the size of which is determined by the desired p-value. For instance, we might say that 52% of Americans prefer tacos to burritos, with a 95% confidence interval of +/- 5%.
#
# 52% (0.52) is the point estimate, and +/- 5% (the interval $[0.47, 0.57]$) is the confidence interval. "95% confidence" means a p-value $\leq 1 - 0.95 = 0.05$.
#
# In this case, the confidence interval includes $0.5$ - which is the natural null hypothesis (that half of Americans prefer tacos and half burritos, thus there is no clear favorite). So in this case, we could use the confidence interval to report that we've failed to reject the null hypothesis.
#
# But providing the full analysis with a confidence interval, including a graphical representation of it, can be a helpful and powerful way to tell your story. Done well, it is also more intuitive to a layperson than simply saying "fail to reject the null hypothesis" - it shows that in fact the data does *not* give a single clear result (the point estimate) but a whole range of possibilities.
#
# How is a confidence interval built, and how should it be interpreted? It does *not* mean that 95% of the data lies in that interval - instead, the frequentist interpretation is "if we were to repeat this experiment 100 times, we would expect the average result to lie in this interval ~95 times."
#
# For a 95% confidence interval and a normal(-ish) distribution, you can simply remember that +/-2 standard deviations contains 95% of the probability mass, and so the 95% confidence interval based on a given sample is centered at the mean (point estimate) and has a range of +/- 2 (or technically 1.96) standard deviations.
#
# Different distributions/assumptions (90% confidence, 99% confidence) will require different math, but the overall process and interpretation (with a frequentist approach) will be the same.
#
# Your assignment - using the data from the prior module ([congressional voting records](https://archive.ics.uci.edu/ml/datasets/Congressional+Voting+Records)):
#
# 1. Generate and numerically represent a confidence interval
# 2. Graphically (with a plot) represent the confidence interval
# 3. Interpret the confidence interval - what does it tell you about the data and its distribution?
#
# Stretch goals:
#
# 1. Write a summary of your findings, mixing prose and math/code/results. *Note* - yes, this is by definition a political topic. It is challenging but important to keep your writing voice *neutral* and stick to the facts of the data. Data science often involves considering controversial issues, so it's important to be sensitive about them (especially if you want to publish).
# 2. Apply the techniques you learned today to your project data or other data of your choice, and write/discuss your findings here.

# %%
# !ls
# Out:
# drugsCom_raw.zip
# LS_DS_142_Sampling_Confidence_Intervals_and_Hypothesis_Testing.ipynb

# %%
# !unzip drugsCom_raw.zip
# Out:
# Archive:  drugsCom_raw.zip
#   inflating: drugsComTest_raw.tsv
#   inflating: drugsComTrain_raw.tsv

# %%
# !ls
# Out:
# drugsCom_raw.zip
# drugsComTest_raw.tsv
# drugsComTrain_raw.tsv
# LS_DS_142_Sampling_Confidence_Intervals_and_Hypothesis_Testing.ipynb

# %%
import pandas as pd
import scipy as stats
import numpy as np

df = pd.read_table('drugsComTest_raw.tsv')
df.describe()
# Out:
#           Unnamed: 0        rating   usefulCount
# count   53766.000000  53766.000000  53766.000000
# mean   116386.701187      6.976900     27.989752
# std     67017.739881      3.285207     36.172833
# min         0.000000      1.000000      0.000000
# 25%     58272.500000      4.000000      6.000000
# 50%    116248.500000      8.000000     16.000000
# 75%    174586.750000     10.000000     36.000000
# max    232284.000000     10.000000    949.000000

# %%
df.head()
# Out:
#    Unnamed: 0         drugName                     condition  \
# 0      163740      Mirtazapine                    Depression
# 1      206473       Mesalamine  Crohn's Disease, Maintenance
# 2      159672          Bactrim       Urinary Tract Infection
# 3       39293         Contrave                   Weight Loss
# 4       97768  Cyclafem 1 / 35                 Birth Control
#
#                                               review  rating  \
# 0  "I&#039;ve tried a few antidepressants over th...    10.0
# 1  "My son has Crohn&#039;s disease and has done ...     8.0
# 2                      "Quick reduction of symptoms"     9.0
# 3  "Contrave combines drugs that were used for al...     9.0
# 4  "I have been on this birth control for one cyc...     9.0
#
#                  date  usefulCount
# 0   February 28, 2012           22
# 1        May 17, 2009           17
# 2  September 29, 2017            3
# 3       March 5, 2017           35
# 4    October 22, 2015            4

# %%
type(df['drugName'])
# Out:
# pandas.core.series.Series

# %%
depression_drugName = df.groupby(['drugName','condition']).groups
print(depression_drugName)
depression_drugName['Mirtazapine', 'Depression']
# Out:
# {('Mirtazapine', 'Depression'): Int64Index([    0,   366,   742,  1996,  2172,  2225,  2251,  2992,  3108,
#              3484,  3801,  4435,  5866,  8729, 10227, 12629, 13446, 13510,
#             14389, 16971, 17136, 17376, 18532, 18783, 19221, 19450, 19972,
#             21095, 21363, 22305, 22548, 24334, 24674, 25596, 25821, 27080,
#             27733, 28124, 30515, 31937, 32154, 32318, 32579, 34052, 34178,
#             35445, 36250, 36528, 38025, 38330, 38784, 40808, 40909, 41758,
#             41884, 41937, 42899, 44134, 44985, 45106, 45518, 45839, 46047,
#             46123, 47106, 47476, 47717, 47932, 48877, 48969, 49308, 50020,
#             50726, 52932, 53221],
#            dtype='int64'), ('Mesalamine', "Crohn's Disease, Maintenance"): Int64Index([    1,  1612,  2387,  9153, 11723, 12275, 13468, 13623, 18458,
#             19903, 21902, 23668, 27356, 30957, 32498, 35727, 42662, 49501,
#             51630],
#            dtype='int64'), ('Bactrim', 'Urinary Tract Infection'): Int64Index([    2,  1859,  1942,  4731,  5860, 14062, 15215, 18956, 23252,
#             23343, 24083, 27759, 29510, 35152, 37467, 37522, 39855, 45507,
#             46716, 49592, 53021],
#            dtype='int64'), ('Contrave', 'Weight Loss'): Int64Index([    3,   412,   541,  2356,  2638,  2871,  3222,  3259,  4319,
#              4359,  4663,  5074,  6280,  6642,  8227,  8382,  9570,  9629,
#             11122, 12805, 13546, 14165, 14239, 14368, 14516, 15302, 15550,
#             15971, 16170, 18158, 19697, 19780, 20563, 22042, 22250, 26490,
#             26530, 28018, 28052, 28107, 28323, 30621, 31435, 34174, 34511,
#             34696, 34777, 34822, 35119, 35288, 35945, 35949, 36440, 37055,
#             37095, 37638, 38909, 39044, 39310, 40409, 40553, 40558, 41400,
#             41799, 41853, 41984, 42959, 43104, 43307, 43541, 43596, 46323,
#             48790, 49351, 49460, 49858, 50588, 51111, 51983, 52782],
#            dtype='int64'), ('Cyclafem 1 / 35', 'Birth Control'): Int64Index([4, 3823, 4567, 14834], dtype='int64'), ('Zyclara', 'Keratosis'): Int64Index([5, 1993, 8855, 17898, 39426, 46093, 46948, 47621], dtype='int64'), ('Copper', 'Birth Control'): Int64Index([    6,   110,   116,   391,  1022,  1563,  2182,  2306,  2353,
#              2517,
#             ...
#             50674, 51113, 51476, 51598, 51704, 51862, 52391, 52576, 52623,
#             53196],
#            dtype='int64', length=193), ('Amitriptyline', 'Migraine Prevention'): Int64Index([    7,  1303,  1589,  1729,  2695,  3349,  3748,  4010,  4640,
#              6439,  6473,  7352,  9107, 10653, 11815, 12726, 12778, 13858,
#             14740, 17333, 17494, 17936, 18253, 18544, 18571, 19495, 19694,
#             20330, 21560, 22572, 23717, 26609, 28005, 29379, 33272, 33795,
#             35328, 37260, 37584, 39433, 40155, 41252, 45455, 47198, 48466,
#             48747, 48782, 49747, 50793, 50797, 51847, 52621, 52942, 53292,
#             53444, 53524],
#            dtype='int64'), ('Methadone', 'Opiate Withdrawal'): Int64Index([    8,  2919,  3713,  3745,  4884,  6112,  8976,  9596, 11629,
#             12661, 13619, 14682, 14786, 15385, 15837, 15838, 16656, 16810,
#             17194, 18735, 21231, 21442, 21769, 22462, 22579, 23933, 24832,
#             25419, 25760, 26090, 26324, 29892, 31139, 31191, 31233, 31313,
#             35023, 35409, 39280, 43813, 45419, 45444, 46960, 47342, 48193,
#             48774, 49008, 49356, 51906, 52228, 53254],
#            dtype='int64'), ('Levora', 'Birth Control'): Int64Index([    9,  2847,  3073,  5120,  5731,  6474, 10775, 11263, 12281,
#             12346, 13969, 14032, 14132, 15471, 15731, 15750, 16054, 17638,
#             18003, 20967, 22570, 24097, 26630, 27110, 30532, 31650, 31651,
#             31656, 31815, 32096, 36430, 36788, 40480, 41881, 43088, 44396,
#             47450, 47771, 51199, 51343, 52605],
#            dtype='int64'), ('Paroxetine', 'Hot Flashes'): Int64Index([   10,  6485,  8844, 14429, 20437, 22676, 22995, 24256, 25063,
#             26687, 26892, 39639, 40933, 44784, 45428, 46943],
#            dtype='int64'), ('Miconazole', 'Vaginal Yeast Infection'): Int64Index([   11,    51,   161,   363,   428,   687,   762,  1265,  1282,
#              1378,
#             ...
#             52170, 52250, 52423, 52533, 52653, 52764, 52799, 52871, 52974,
#             53592],
#            dtype='int64', length=341), ('Belviq', 'Weight Loss'): Int64Index([   12,   232,   600,   643,   885,  1840,  1924,  2055,  2487,
#              3451,
#             ...
#             51860, 51936, 52360, 52896, 53547, 53548, 53576, 53696, 53713,
#             53750],
#            dtype='int64', length=127), ('Seroquel', 'Schizoaffective Disorde'): Int64Index([13, 6304, 12994, 18175, 28413, 38541, 41542, 45383, 45846, 50749], dtype='int64'), ('Ambien', 'Insomnia'): Int64Index([   14,   252,   334,   377,  1233,  1234,  1322,  1576,  1808,
#              1826,  2125,  2154,  2198,  2898,  3049,  3137,  4698,  5064,
#              6083,  6975,  7452,  7967,  8262,  8911,  9150,  9616, 13494,
#             13538, 13635, 14306, 14415, 15647, 15717, 16048, 16103, 16929,
#             17687, 18037, 18343, 20466, 20553, 21331, 21592, 21765, 22190,
#             22507, 22808, 25866, 25951, 26279, 27334, 28530, 29986, 31269,
#             31865, 32981, 33008, 34019, 34446, 34501, 35260, 35593, 35801,
#             36753, 37908, 38281, 38283, 38553, 38697, 38829, 39505, 39837,
#             41353, 41825, 42100, 42579, 42605, 43170, 43270, 44267, 45714,
#             46578, 47115, 47137, 47623, 48315, 49397, 49536, 51139, 51639,
#             52197, 52266, 52723, 52797, 53014],
#            dtype='int64'), ('Nuvigil', 'Narcolepsy'): Int64Index([   15,  5008,  5370,  5881,  6592,  7088, 16315, 18118, 18162,
#             23688, 23955, 27245, 36200, 36987, 41901, 46865, 48014],
#            dtype='int64'), ('Chantix', 'Smoking Cessation'): Int64Index([   16,   499,   692,   730,   947,   991,  1455,  2238,  2261,
#              2758,
#             ...
#             52153, 52274, 52398, 52608, 52661, 52734, 52940, 53251, 53481,
#             53751],
#            dtype='int64', length=224), ('Microgestin Fe 1 / 20', 'Acne'): Int64Index([17, 7754, 8102, 32402, 42938], dtype='int64'), ('Klonopin', 'Bipolar Disorde'): Int64Index([   18,   498,  3532,  6412, 12730, 13078, 16643, 27006, 33437,
#             42716, 43752, 46193, 48470, 51701],
#            dtype='int64'), ('Ciprofloxacin', 'Urinary Tract Infection'): Int64Index([   19,  1414,  1835,  2322,  3059,  4044,  4889,  6728,  8465,
#              8897,  9102,  9380, 10796, 11380, 11646, 12229, 12439, 12846,
#             15009, 15368, 15818, 17517, 20215, 20545, 20783, 20880, 21335,
#             21973, 22792, 22874, 23565, 23750, 24286, 28091, 28273, 28879,
#             29497, 29811, 30257, 30357, 32673, 32836, 33142, 33279, 33429,
#             36754, 36757, 37871, 40955, 41320, 41654, 43879, 44188, 44297,
#             47810, 47991, 50430, 52143, 52846, 52952, 53529],
#            dtype='int64'), ('Trazodone', 'Insomnia'): Int64Index([   20,  1024,  1099,  1111,  1341,  2885,  3286,  4110,  4634,
#              4666,
#             ...
#             50786, 51099, 51249, 51581, 51634, 52145, 52404, 52600, 52709,
#             53530],
#            dtype='int64', length=135), ('EnteraGam', 'Irritable Bowel Syndrome'): Int64Index([21], dtype='int64'), ('Aripiprazole', 'Bipolar Disorde'): Int64Index([   22,    93,   881,  1537,  3627,  6031,  6033,  7241,  7540,
#              7586,  9423, 11370, 11506, 12640, 13440, 15218, 17101, 17103,
#             17642, 18074, 20172, 20489, 20491, 21047, 21587, 21621, 24028,
#             24746, 24906, 24917, 25692, 26236, 27372, 29367, 29377, 29488,
#             31296, 31935, 33197, 33920, 34199, 34314, 35883, 40186, 40443,
#             40580, 40930, 41074, 43554, 49005, 49170, 49176, 50692, 50945],
#            dtype='int64'), ('Cyclosporine', 'Keratoconjunctivitis Sicca'): Int64Index([   23,  1669, 12744, 19183, 21623, 22447, 22787, 27303, 27502,
#             37007, 38041, 43356, 44236, 44316, 45321, 46037, 48546],
#            dtype='int64'), ('Oxybutynin', 'Hyperhidrosis'): Int64Index([24, 4171, 12210, 24462, 24574, 28904, 31393, 33967, 36066, 49652,
#             51808],
#            dtype='int64'), ('Lurasidone', 'Bipolar Disorde'): Int64Index([   25,   160,   806,  1005,  1718,  2772,  3309,  3719,  4256,
#              5106,  5502,  6166,  6398,  6797,  7991,  8284,  8810,  9445,
#             10466, 10857, 10865, 11288, 12901, 13412, 14403, 15247, 15274,
#             15463, 15555, 16667, 16729, 16943, 17957, 18102, 18861, 19479,
#             19606, 20761, 21790, 22758, 23301, 23397, 23595, 24195, 25190,
#             25738, 26264, 27100, 27130, 27746, 28514, 29040, 29387, 29829,
#             29880, 30524, 31968, 32701, 33246, 34525, 35419, 35645, 35691,
#             36103, 36290, 36944, 37300, 37502, 37784, 37982, 38396, 39651,
#             40849, 40923, 41931, 42488, 42801, 42804, 43177, 43920, 44056,
#             44216, 45234, 45998, 46728, 46782, 47007, 47610, 47739, 47799,
#             48481, 48954, 49077, 50835, 51128, 51836, 51942, 52632, 52706],
#            dtype='int64'), ('Clonazepam', 'Panic Disorde'): Int64Index([   26,   618,  2682,  4931,  5237,  6874,  7730,  8606, 10351,
#             11104, 11303, 12198, 13049, 13155, 13248, 13944, 15272, 17367,
#             17486, 18044, 18864, 20309, 21205, 22026, 23669, 24069, 24775,
#             27190, 28120, 28976, 31456, 31527, 32747, 33257, 34504, 37727,
#             37745, 38896, 39879, 40494, 42536, 42563, 43178, 43226, 43434,
#             43495, 44118, 44461, 44641, 44776, 45387, 45427, 46353, 46373,
#             47400, 47406, 48322, 48998, 49581, 50464, 51332, 51562, 52001,
#             52591, 53305],
#            dtype='int64'), ('Ciclopirox', 'Onychomycosis, Fingernail'): Int64Index([27], dtype='int64'), ('Sodium oxybate', 'Narcolepsy'): Int64Index([   28,  5063,  6828, 13900, 15116, 18448, 18579, 23786, 25036,
#             32653, 34518, 38500, 39564, 40866, 42466, 53278],
#            dtype='int64'), ('Lamotrigine', 'Bipolar Disorde'): Int64Index([   29,   393,   437,  1412,  1780,  2223,  2485,  3157,  4028,
#              4372,
#             ...
#             50886, 51012, 51207, 51929, 52126, 52513, 52701, 52827, 53420,
#             53669],
#            dtype='int64', length=143), ('Blisovi Fe 1 / 20', 'Birth Control'): Int64Index([   30,  1628,  6583, 12794, 12881, 13740, 24504, 28918, 34917,
#             46418, 47118, 47796, 49034, 50587],
#            dtype='int64'), ('Ivermectin', 'Rosacea'): Int64Index([   31,  2013,  7642,  8135, 13158, 13295, 13677, 15205, 15664,
#             16062, 17856, 18340, 18603, 18794, 40879, 42154, 42673, 42862,
#             46798, 47104, 47694, 48672],
#            dtype='int64'), ('Suprep Bowel Prep Kit', 'Bowel Preparation'): Int64Index([   32,   262,   519,   640,   684,   950,   994,  1042,  1113,
#              1343,
#             ...
#             50591, 50655, 50808, 50831, 50880, 51150, 51292, 51367, 52064,
#             52672],
#            dtype='int64', length=209), ('Movantik', 'Constipation, Drug Induced'): Int64Index([   33,  9073, 11425, 11971, 12628, 16489, 19795, 20514, 24952,
#             27103, 27160, 28153, 29083, 29485, 31598, 36218, 40257, 40678,
#             43507, 46784, 47053, 47432, 47946, 48416, 49554, 51650],
#            dtype='int64'), ('Lorcaserin', nan): Int64Index([34, 35562], dtype='int64'), ('Actos', 'Diabetes, Type 2'): Int64Index([35, 7785, 8784, 16875, 22681, 30417, 39553], dtype='int64'), ('Duloxetine', 'Pain'): Int64Index([36, 358, 527, 18738, 20708, 21492, 24657, 26853, 38127, 44576,
#             45000, 45720],
#            dtype='int64'), ('NuvaRing', 'Birth Control'): Int64Index([   37,   321,   421,   661,  1307,  1650,  2374,  2494,  2520,
#              2625,
#             ...
#             50426, 50488, 50522, 50767, 51791, 52148, 53266, 53646, 53674,
#             53694],
#            dtype='int64', length=204), ('Escitalopram', 'Depression'): Int64Index([   38,   135,  1623,  2014,  2858,  3275,  3696,  3701,  4176,
#              4313,
#             ...
#             48140, 48146, 48452, 48962, 49107, 49643, 49709, 50108, 50324,
#             52352],
#            dtype='int64', length=135), ('Tesamorelin', 'Lipodystrophy'): Int64Index([39, 49710], dtype='int64'), ('Campral', 'Alcohol Dependence'): Int64Index([   40,    80,  1227,  2917,  3751,  4906,  5463,  7713, 11168,
#             13479, 13766, 14835, 17142, 18078, 18708, 20605, 21557, 26205,
#             28365, 30574, 30838, 31921, 32546, 33598, 35493, 35899, 37686,
#             40192, 40310, 42725, 52403],
#            dtype='int64'), ('Gabapentin', 'Bipolar Disorde'): Int64Index([   41,  1712,  1837,  4497,  6594, 15410, 17259, 18664, 22221,
#             23509, 23644, 23681, 26063, 32783, 34499, 44313, 44469, 44518,
#             45626, 46399],
#            dtype='int64'), ('Levonorgestrel', 'Emergency Contraception'): Int64Index([   42,    82,   103,   148,   352,   432,   521,   526,   923,
#               962,
#             ...
#             52714, 52775, 52807, 52969, 53197, 53499, 53585, 53616, 53680,
#             53729],
#            dtype='int64', length=430), ('Aubra', 'Birth Control'): Int64Index([   43,   983,  2601,  3340,  3838,  5046,  5098,  7442,  8783,
#              9009, 12613, 13106, 15542, 16284, 16655, 19513, 21193, 23267,
#             24752, 24768, 25069, 29516, 29900, 30580, 32953, 35769, 36274,
#             43247, 45879, 45963, 48868, 52309],
#            dtype='int64'), ('Plan B One-Step', 'Emergency Contraception'): Int64Index([   44,   323,   446,   653,  1246,  1386,  2280,  3400,  3847,
#              3860,
#             ...
#             49733, 49818, 50388, 50529, 51492, 51514, 51947, 52401, 52583,
#             53661],
#            dtype='int64', length=128), ('Ethinyl estradiol / etonogestrel', 'Birth Control'): Int64Index([   45,   247,   577,   912,  1656,  1954,  2108,  2842,  3347,
#              3356,
#             ...
#             50998, 51030, 51359, 52386, 52645, 52655, 52660, 53011, 53350,
#             53562],
#            dtype='int64', length=196), ('Microgestin Fe 1.5 / 30', 'Birth Control'): Int64Index([   46,   336,  2457,  7361,  8199, 10058, 23589, 25988, 28516,
#             30122, 31329, 31693, 47760, 49738, 51781],
#            dtype='int64'), ('Wellbutrin', 'Major Depressive Disorde'): Int64Index([   47,  4193,  4945, 14388, 16607, 17633, 20006, 25242, 34002,
#             39994, 40083, 41419, 42270, 52485, 53273],
#            dtype='int64'), ('Clonazepam', 'Anxiety'): Int64Index([   48,   208,   515,   529,   786,  1223,  1742,  2282,  3127,
#              3208,
#             ...
#             49931, 50150, 50221, 50279, 50465, 50819, 50920, 51843, 52236,
#             53013],
#            dtype='int64', length=136), ('Benzoyl peroxide / clindamycin', 'Acne'): Int64Index([   49,   641,   655,  2439,  3844,  3922,  4453,  4699,  4855,
#              5582,  5600,  6952,  8267,  8681,  8786,  9642, 10566, 11110,
#             13326, 13508, 13762, 14191, 15948, 19460, 19893, 20321, 20387,
#             20907, 21195, 22149, 22358, 22903, 22920, 23309, 23609, 23780,
#             24345, 24476, 24895, 26304, 26395, 27182, 27416, 28038, 29426,
#             29527, 30300, 31051, 31423, 31478, 32058, 32065, 32893, 33252,
#             33316, 33923, 34528, 34834, 34900, 35184, 36086, 36397, 37444,
#             37646, 37787, 37948, 38205, 38755, 40688, 41523, 42636, 44083,
#             44178, 44861, 45181, 45241, 46308, 48145, 48653, 48938, 49736,
#             50222, 50274, 50841, 51067, 51428, 51496, 51682, 52646, 52696,
#             52724, 52745, 53026, 53087],
#            dtype='int64'), ('Etonogestrel', 'Birth Control'): Int64Index([   50,    53,   218,   251,   295,   315,   443,   447,   493,
#               535,
#             ...
#             53175, 53227, 53247, 53260, 53303, 53324, 53409, 53553, 53663,
#             53720],
#            dtype='int64', length=1080), ('Nitrofurantoin', 'Bladder Infection'): Int64Index([   52,   466,   475,  3315,  3835,  4397,  6063,  6662,  9051,
#              9916, 10273, 11621, 14810, 14823, 15751, 16150, 16331, 16548,
#             18084, 18330, 18892, 18990, 19584, 19643, 20224, 20503, 22106,
#             23472, 23503, 23588, 24687, 25985, 26595, 31995, 34679, 38293,
#             38923, 40946, 44697, 45358, 47726, 48135, 48190, 51391, 51697,
#             52891, 52979],
#            dtype='int64'), ('Ortho Tri-Cyclen Lo', 'Birth Control'): Int64Index([   54,   540,   678,  2649,  3577,  8553,  9019,  9329,  9776,
#             10403, 11284, 11342, 11956, 12982, 13185, 14592, 15005, 16234,
#             16311, 16591, 17592, 20732, 24533, 24551, 25120, 27128, 28437,
#             29545, 30171, 32102, 32969, 33468, 34161, 35094, 38572, 39380,
#             42126, 42398, 43992, 44212, 44292, 44492, 45192, 46441, 46872,
#             47658, 47822, 48643, 48957, 49487, 49956, 50489, 50984, 52277,
#             52490, 52835, 53467],
#            dtype='int64'), ('Tamsulosin', 'Benign Prostatic Hyperplasia'): Int64Index([   55,   964,  3326,  4235,  5114,  8776, 10829, 13615, 16991,
#             18982, 19002, 19627, 20853, 24512, 26208, 26210, 26728, 27589,
#             27841, 30869, 31250, 34932, 35404, 37001, 39039, 40448, 41152,
#             44013, 46456, 46788, 50373],
#            dtype='int64'), ('Tofacitinib', 'Rheumatoid Arthritis'): Int64Index([56, 1659, 13498, 24225, 25170, 25570, 26428, 35428, 39334, 40918,
#             46127, 46325],
#            dtype='int64'), ('Cryselle', 'Endometriosis'): Int64Index([57, 23096, 48840], dtype='int64'), ('Amphetamine / dextroamphetamine', 'ADHD'): Int64Index([   58,   695,  1142,  1724,  4541,  4645,  5224,  5306,  5833,
#              6272,
#             ...
#             49679, 50044, 50603, 50818, 51036, 51061, 51813, 51830, 52614,
#             52882],
#            dtype='int64', length=103), ('Clindamycin', 'Acne'): Int64Index([   59,  1208,  8123, 11316, 14244, 15533, 21467, 24228, 24258,
#             25027, 36619, 42691, 42936, 43454, 43710, 50852, 52425],
#            dtype='int64'), ('Pramipexole', 'Restless Legs Syndrome'): Int64Index([   60,   941,  1249,  1662,  4924,  5123,  6894,  8354,  9866,
#             11714, 12519, 13634, 14915, 16483, 16761, 18071, 19727, 20870,
#             21387, 23926, 28880, 35174, 35177, 36665, 36934, 38170, 38925,
#             38958, 40167, 42929, 43838, 45899, 47426, 48143, 48732, 53315,
#             53716],
#            dtype='int64'), ('Skyla', 'Birth Control'): Int64Index([   61,   289,   400,   463,   675,   772,   802,   976,  1082,
#              1192,
#             ...
#             51877, 52245, 52491, 52640, 52678, 53119, 53163, 53512, 53515,
#             53516],
#            dtype='int64', length=252), ('Lastacaft', 'Conjunctivitis, Allergic'): Int64Index([62, 5890, 11594, 34723], dtype='int64'), ('Effexor XR', 'Anxiety'): Int64Index([   63,  1108,  3117,  4064,  4464,  6529,  6793,  9100, 10093,
#             14896, 15785, 15957, 16255, 21857, 23119, 23675, 28579, 28853,
#             30947, 32728, 32738, 32842, 33663, 37712, 39881, 40867, 41551,
#             42913, 43468, 47447, 48521, 49599, 51307, 52571],
#            dtype='int64'), ('Nifedipine', "Raynaud's Syndrome"): Int64Index([64, 20046, 26934, 27693, 36191, 41280, 51977, 52413], dtype='int64'), ('Lurasidone', 'Schizophrenia'): Int64Index([   65,   749,  9045, 10344, 13182, 15512, 18759, 23100, 24588,
#             25116, 28004, 30261, 39454, 42197, 42346, 49968, 52076],
#            dtype='int64'), ('Afrezza', 'Diabetes, Type 1'): Int64Index([66, 13109, 42327, 46915], dtype='int64'), ('Zoloft', 'Depression'): Int64Index([   67,   130,   235,   277,   658,   700,   782,  1543,  3449,
#              3862,
#             ...
#             47937, 48028, 48173, 48662, 49700, 49972, 50992, 51599, 51703,
#             52454],
#            dtype='int64', length=105), ('Ziprasidone', 'Schizophrenia'): Int64Index([68, 7631, 11005, 11992, 12521, 20291, 25810, 31471, 33917, 51999], dtype='int64'), ('Bactrim', 'Kidney Infections'): Int64Index([69, 14524], dtype='int64'), ('Ethinyl estradiol / norethindrone', 'Birth Control'): Int64Index([   70,   139,   191,   226,   492,   648,   713,   726,   744,
#               745,
#             ...
#             53274, 53294, 53379, 53382, 53403, 53438, 53493, 53614, 53671,
#             53677],
#            dtype='int64', length=744), ('Sertraline', 'Major Depressive Disorde'): Int64Index([   71,   662,  7495,  8141, 10322, 10520, 15175, 20066, 27781,
#             27887, 31918, 33942, 35317, 35773, 36038, 36204, 39774, 43242,
#             50062, 50781, 52638, 53093],
#            dtype='int64'), ('Aluminum chloride hexahydrate', 'Hyperhidrosis'): Int64Index([   72,   651,   853,  1676,  1708,  1841,  1853,  2876,  3648,
#              3764,
#             ...
#             49198, 49249, 50001, 51398, 51539, 51648, 51779, 52275, 53236,
#             53358],
#            dtype='int64', length=113), ('Effexor XR', 'Depression'): Int64Index([   73,   149,  1461,  1734,  2417,  2819,  2862,  3544,  4877,
#              5289,  5336,  6223,  9954, 10335, 11638, 12289, 12546, 13648,
#             14097, 15303, 18896, 19014, 21753, 21895, 23077, 24761, 25826,
#             26019, 27611, 28986, 30923, 31255, 31375, 32822, 33239, 34787,
#             35942, 35982, 36990, 37127, 39439, 40193, 40814, 42791, 43359,
#             44845, 46116, 46767, 47140, 47678, 48350, 48624, 49562, 51502,
#             52134, 52900],
#            dtype='int64'), ('ParaGard', 'Birth Control'): Int64Index([   74,   194,   426,   450,   471,   729,  1432,  1465,  1683,
#              1869,
#             ...
#             49251, 49256, 49421, 49469, 49474, 50727, 51042, 51133, 51493,
#             51923],
#            dtype='int64', length=140), ('Pregabalin', 'Generalized Anxiety Disorde'): Int64Index([   75,  3584,  6343,  6842,  7344,  7921,  8345,  8433,  8872,
#              9738, 10860, 11880, 12317, 14162, 18124, 20995, 21478, 22798,
#             23694, 23925, 27734, 28577, 29190, 31800, 34111, 34919, 35064,
#             35551, 36549, 38180, 38727, 39577, 42099, 42381, 46383, 50580,
#             50601, 50746, 52014],
#            dtype='int64'), ('Ethinyl estradiol / levonorgestrel', 'Birth Control'): Int64Index([   76,   246,   261,   414,   524,   594,   891,   927,   935,
#              1046,
#             ...
#             53261, 53268, 53322, 53486, 53525, 53540, 53640, 53642, 53652,
#             53717],
#            dtype='int64', length=507), ('Ultram', 'Pain'): Int64Index([   77,  2978,  3773,  6918,  7185,  8466,  9394, 11553, 11671,
#             15118, 15850, 16229, 16635, 18918, 20080, 20117, 20133, 24274,
#             26079, 26733, 32021, 33848, 35537, 41018, 41574, 42055, 45115,
#             49096, 52912],
#            dtype='int64'), ('Phentermine', 'Obesity'): Int64Index([   78,   775,   978,  1575,  2081,  2163,  2852,  4522,  4770,
#              5898,  7078,  8933,  9008,  9254,  9653,  9762,  9928, 12049,
#             12116, 12246, 12697, 13534, 15256, 15381, 15400, 15703, 16539,
#             16861, 18391, 18410, 19062, 19253, 19965, 20087, 21129, 21797,
#             22411, 24020, 24134, 25881, 25961, 26181, 27205, 27429, 28010,
#             28113, 28526, 28997, 29022, 31304, 32068, 33603, 34003, 34553,
#             34989, 35568, 37749, 37966, 38711, 38980, 39204, 39605, 40829,
#             40865, 41912, 42464, 42736, 43082, 43324, 43425, 43853, 44888,
#             45245, 45750, 47505, 47587, 47594, 47843, 48077, 49978, 50052,
#             50503, 50515, 51126, 51256, 51692, 51990, 52431, 52978, 53130,
#             53150, 53421],
#            dtype='int64'), ('Venlafaxine', 'Depression'): Int64Index([   79,    81,   223,   798,   810,  1590,  1632,  1736,  2571,
#              2989,
#             ...
#             48277, 48576, 49229, 50145, 50979, 51240, 51470, 52022, 52904,
#             52953],
#            dtype='int64', length=137), ('BuSpar', 'Anxiety'): Int64Index([   83,   133,   311,  4566,  5932,  7705,  8076, 10452, 10962,
#             11325, 12119, 12372, 14351, 15422, 15697, 16700, 18684, 19069,
#             20194, 20982, 21186, 21325, 21781, 23465, 23705, 24339, 27736,
#             28417, 28463, 28621, 28709, 30052, 31529, 31751, 32757, 33332,
#             33467, 34414, 35092, 37509, 37688, 38824, 39186, 40893, 41306,
#             42221, 42983, 43026, 43651, 43689, 44311, 45795, 46251, 46447,
#             46812, 47427, 47630, 48230, 48243, 48337, 48964, 49646, 51714,
#             51716, 52011, 52190, 52316, 52915, 53096, 53753],
#            dtype='int64'), ('Acetaminophen / hydrocodone', 'Pain'): Int64Index([   84,    97,   857,   892,  1090,  1298,  1318,  1730,  2698,
#              3160,
#             ...
#             50174, 50906, 50921, 51646, 51656, 51776, 52916, 53007, 53118,
#             53423],
#            dtype='int64', length=120), ('Aviane', 'Birth Control'): Int64Index([   85,   243,   435,   553,  2115,  2648,  3004,  3327,  3433,
#              4352,  4638,  5887,  6188,  7438,  8670,  9128, 10029, 10660,
#             10777, 10992, 11047, 13063, 14425, 15394, 15564, 16043, 16619,
#             17469, 18691, 19650, 20038, 20891, 21090, 21327, 21635, 24318,
#             24611, 24782, 25330, 25620, 25915, 26987, 27831, 28943, 29318,
#             29553, 30892, 31013, 31616, 32327, 33186, 33610, 34219, 34354,
#             34386, 35209, 35299, 35305, 35442, 35730, 37314, 37428, 37508,
#             38120, 38986, 40061, 41057, 41116, 41733, 43344, 43970, 45797,
#             45957, 46426, 46614, 47707, 48455, 49656, 50093, 50158, 50756,
#             50994, 51116, 51615, 51924],
#            dtype='int64'), ('Inderal', 'Migraine Prevention'): Int64Index([86, 2983, 3027, 7188, 10797, 22710, 44052, 47170, 49933], dtype='int64'), ('Promethazine', 'Nausea/Vomiting'): Int64Index([   87,  6920,  8915,  9431, 10366, 10639, 11487, 11988, 16829,
#             19218, 19774, 22058, 23779, 23964, 25417, 27790, 30631, 33184,
#             33961, 36386, 38193, 39623, 41307, 43611, 44804, 47091, 47491,
#             47899, 48159, 51213],
#            dtype='int64'), ('Tioconazole', 'Vaginal Yeast Infection'): Int64Index([   88,   144,   233,   549,  1098,  1172,  1177,  1407,  1641,
#              1715,
#             ...
#             52346, 52365, 52838, 52947, 52968, 53100, 53208, 53311, 53572,
#             53689],
#            dtype='int64', length=274), ('Orthovisc', 'Osteoarthritis'): Int64Index([   89,  4011,  6847,  8546,  8617,  9001,  9334,  9932, 10747,
#             15257, 15603, 17733, 18954, 21505, 22490, 25625, 25671, 30130,
#             31408, 35834, 38365, 40228, 40294, 50101],
#            dtype='int64'), ('Implanon', 'Birth Control'): Int64Index([   90,   228,   302,   374,   482,   504,   538,   575,   716,
#              1025,
#             ...
#             52511, 52702, 52780, 52996, 53241, 53334, 53346, 53377, 53627,
#             53666],
#            dtype='int64', length=401), ('Marezine', 'Motion Sickness'): Int64Index([91, 4159, 50273], dtype='int64'), ('Levonorgestrel', 'Birth Control'): Int64Index([   92,    99,   210,   217,   283,   297,   474,   520,   528,
#               547,
#             ...
#             53462, 53483, 53509, 53513, 53559, 53615, 53625, 53690, 53741,
#             53763],
#            dtype='int64', length=755), ('Minoxidil', 'High Blood Pressure'): Int64Index([94, 6118], dtype='int64'), ('Humira', 'Psoriatic Arthritis'): Int64Index([95, 1944, 3533, 7961, 10451, 18932, 22711, 34824, 44851, 49813,
#             50115],
#            dtype='int64'), ('Insulin inhalation, rapid acting', 'Diabetes, Type 1'): Int64Index([96, 8362, 14000, 18468, 19136, 27949, 30610, 33637, 43590, 47204], dtype='int64'), ('Phenazopyridine', 'Interstitial Cystitis'): Int64Index([98, 4966, 6209, 8482, 10175, 17543, 42881, 49662, 52868], dtype='int64'), ('Clonidine', 'ADHD'): Int64Index([100, 8725, 9524, 11619, 14898, 17877, 18163, 27610, 27794, 48991,
#             52447, 53466],
#            dtype='int64'), ('Ethinyl estradiol / norgestimate', 'Birth Control'): Int64Index([  101,   127,   276,   635,   669,   676,   797,  1040,  1054,
#              1267,
#             ...
#             52955, 52956, 52977, 53155, 53219, 53258, 53354, 53644, 53697,
#             53699],
#            dtype='int64', length=517), ('Nicoderm CQ', 'Smoking Cessation'): Int64Index([  102,  7265,  8068, 11176, 18869, 19355, 28701, 30513, 32382,
#             32608, 33905, 39195, 48513, 48862, 51590],
#            dtype='int64'), ('Celecoxib', 'Osteoarthritis'): Int64Index([104, 4519, 4817, 17071, 17847, 20540, 22176, 32086, 33974, 38544,
#             46085, 48065],
#            dtype='int64'), ('Fluoxetine', 'Major Depressive Disorde'): Int64Index([  105,  5896, 13449, 22718, 23075, 30062, 31452, 33767, 36837,
#             40833, 41258, 45836, 46710, 49228],
#            dtype='int64'), ('Topamax', 'Migraine Prevention'): Int64Index([  106,   442,   877,  2418,  2974,  5178,  5201,  5213,  7685,
#              8652,  9157,  9679, 10378, 13073, 13399, 14991, 15708, 15792,
#             16428, 16443, 16584, 17409, 17489, 18681, 19262, 21250, 22654,
#             23165, 23575, 24648, 26586, 27373, 27422, 27724, 27744, 28228,
#             29174, 30844, 31829, 34013, 34677, 37171, 37244, 39000, 39343,
#             39613, 41645, 42151, 44665, 44737, 45663, 45952, 46026, 46070,
#             48081, 48216, 48501, 51485, 52177, 53608],
#            dtype='int64'), ('Depakote', 'Bipolar Disorde'): Int64Index([  107, 10097, 18119, 18776, 19351, 20198, 20586, 26935, 29451,
#             31708, 32675, 40957, 41340, 43949, 44133, 45932, 47673, 48976,
#             51058, 51858, 53004],
#            dtype='int64'), ('Riboflavin', 'Migraine Prevention'): Int64Index([108], dtype='int64'), ('Lo Loestrin Fe', 'Birth Control'): Int64Index([  109,   126,   431,   932,  1049,  1456,  1775,  1951,  2006,
#              2248,
#             ...
#             51789, 52075, 52113, 52748, 52761, 52770, 52817, 53194, 53364,
#             53707],
#            dtype='int64', length=229), ('Drospirenone / estradiol', 'Postmenopausal Symptoms'): Int64Index([111, 5858, 6145, 7511, 21443, 42080, 42629, 43584, 52721], dtype='int64'), ('Bupropion', 'Depression'): Int64Index([  112,   122,   203,   318,   477,   900,   965,  1007,  1354,
#              1367,
#             ...
#             52089, 52430, 52562, 52783, 52833, 53183, 53281, 53384, 53447,
#             53505],
#            dtype='int64', length=198), ('Bacitracin / neomycin / polymyxin b', 'Bacterial Skin Infection'): Int64Index([113], dtype='int64'), ('Phentermine', 'Weight Loss'): Int64Index([  114,   351,   407,   420,   438,   634,   949,  1051,  1056,
#              1323,
#             ...
#             52950, 52976, 52993, 53002, 53039, 53184, 53279, 53394, 53561,
#             53687],
#            dtype='int64', length=439), ('Yaz', 'Birth Control'): Int64Index([  115,   337,  1499,  2286,  2515,  2594,  2791,  4871,  5323,
#              5450,  6359,  6902,  7604,  7620,  8367,  9785,  9988, 10912,
#             11008, 11235, 11718, 12643, 14724, 15023, 15070, 16385, 17161,
#             17392, 17881, 18878, 19067, 19744, 20152, 20415, 20505, 20875,
#             21417, 22336, 23128, 23803, 23997, 24156, 24255, 24803, 25486,
#             26975, 27034, 27342, 27649, 27739, 28744, 29110, 29156, 30517,
#             32990, 34836, 36312, 36676, 37299, 37641, 38274, 41462, 42194,
#             42390, 42452, 42456, 42892, 43047, 43078, 45382, 45719, 47033,
#             48121, 48439, 49348, 49426, 50171, 51297, 51888, 53401],
#            dtype='int64'), ('Amitriptyline', 'ibromyalgia'): Int64Index([  117,   404,  1000,  3653,  8237,  8924,  9880, 18812, 19783,
#             20316, 21321, 27041, 27851, 28203, 35270, 35300, 37102, 41002,
#             42022, 43147, 44493, 47493, 48204, 51217, 52311],
#            dtype='int64'), ('Jolessa', 'Birth Control'): Int64Index([  118, 13245, 17582, 24569, 26172, 30279, 30818, 30935, 31646,
#             31670, 31803, 32555, 33441, 33539, 39052, 47877, 48518, 50878,
#             53508],
#            dtype='int64'), ('Guaifenesin / pseudoephedrine', 'Cough and Nasal Congestion'): Int64Index([  119,  2495,  2935,  4134,  5052,  5250,  7588,  8155, 10441,
#             12527, 13820, 16747, 17354, 18538, 19132, 21711, 23665, 26675,
#             27296, 28424, 28818, 31322, 32367, 34524, 35392, 35971, 36431,
#             37981, 38761, 41473, 41494, 45249, 47220, 53174, 53526, 53665],
#            dtype='int64'), ('Oxycodone', 'Pain'): Int64Index([  120,   345,   370,   440,  1802,  2916,  3585,  4274,  4951,
#              5553,  6037,  6516,  6877,  7093,  7799,  7850,  8158,  8315,
#              8371,  9400,  9448,  9484, 10549, 11021, 11295, 11348, 11479,
#             14535, 15747, 17443, 17514, 17596, 17786, 18692, 19032, 19561,
#             21625, 21817, 21828, 21842, 22261, 22967, 23011, 23587, 23931,
#             24085, 24297, 25171, 25646, 25680, 26211, 28187, 28331, 29344,
#             29705, 32005, 32403, 32601, 33533, 34209, 34434, 35578, 36448,
#             36643, 36792, 36880, 37090, 37983, 38310, 38546, 38607, 38693,
#             38745, 39369, 40338, 40514, 40790, 42030, 43143, 44516, 45123,
#             46059, 46867, 47875, 49854, 49866, 50800, 50988, 51086, 51100,
#             51410, 51429, 51483, 51679, 52371, 52375, 52378, 52601, 52985],
#            dtype='int64'), ('Nexplanon', 'Birth Control'): Int64Index([  121,   185,   241,   340,   369,   419,   580,   829,   859,
#               875,
#             ...
#             53127, 53132, 53178, 53188, 53331, 53388, 53446, 53472, 53543,
#             53551],
#            dtype='int64', length=734), ('Brisdelle', 'Hot Flashes'): Int64Index([123, 5906, 6261, 14186, 20620, 33456, 47127, 48022], dtype='int64'), ('Bupropion', 'Smoking Cessation'): Int64Index([  124,   606,  4988,  5257,  5506,  7682,  8965,  9074, 10564,
#             11167, 16216, 16272, 17474, 17921, 18238, 21899, 24238, 24626,
#             26106, 26637, 26791, 27339, 27474, 28172, 28275, 29142, 30962,
#             31345, 32401, 32605, 32733, 33160, 33350, 34885, 36370, 36559,
#             37450, 37482, 38173, 39117, 41598, 42883, 43926, 44136, 47329,
#             47757, 48859, 49209, 49935, 51695, 52339, 53701],
#            dtype='int64'), ('Beyaz', 'Acne'): Int64Index([125, 833, 11037, 45342, 47557, 48563, 53544], dtype='int64'), ('Yasmin', 'Acne'): Int64Index([  128,  4801,  7107,  8816,  9469, 15539, 16575, 17008, 17252,
#             18262, 18531, 19565, 20234, 26165, 26693, 30360, 30371, 36436,
#             37076, 38335, 42819, 49020, 49465, 52010],
#            dtype='int64'), ('Bupropion', 'ADHD'): Int64Index([  129,  6838,  8714,  8865, 12162, 17120, 28041, 29566, 31110,
#             37117, 38844, 40159, 44364, 51336],
#            dtype='int64'), ('Nucynta ER', 'Diabetic Peripheral Neuropathy'): Int64Index([131, 2696], dtype='int64'), ('Prozac', 'Major Depressive Disorde'): Int64Index([  132,  1591, 12958, 17375, 33596, 36932, 37504, 37576, 39997,
#             40229, 40917, 42682, 45845, 46514, 50043],
#            dtype='int64'), ('Kariva', 'Birth Control'): Int64Index([  134,  1217,  3200,  7170,  8754, 21445, 22499, 24143, 27072,
#             29505, 29838, 33259, 39070, 41271, 43135, 48030, 51009, 51134],
#            dtype='int64'), ('Microgestin Fe 1 / 20', '12</span> users found this comment helpful.'): Int64Index([136], dtype='int64'), ('Liraglutide', 'Diabetes, Type 2'): Int64Index([  137,  1625,  1888,  2059,  2640,  2717,  3219,  4510,  5062,
#              5729,  7348,  7623,  7645,  9507,  9854, 10346, 10355, 11334,
#             11946, 12118, 12647, 15456, 16493, 16762, 16898, 17050, 18507,
#             18576, 19110, 19239, 19898, 23680, 24984, 25295, 26547, 27526,
#             28282, 28618, 29153, 29836, 30522, 31181, 31894, 31896, 32221,
#             32291, 32368, 32782, 32956, 33411, 33667, 34035, 34056, 34112,
#             35622, 36230, 36742, 36997, 37443, 37625, 37895, 38217, 38368,
#             38446, 38616, 39028, 40747, 41129, 41497, 42092, 43025, 43288,
#             43681, 44701, 45112, 45391, 45592, 46389, 46991, 47054, 48999,
#             49159, 51354, 51868, 52189, 53056, 53168, 53192, 53672],
#            dtype='int64'), ('Sutent', 'Renal Cell Carcinoma'): Int64Index([138, 2891, 8054], dtype='int64'), ('Tramadol', 'Pain'): Int64Index([  140,   256,  1134,  1336,  1976,  2771,  3221,  3233,  3655,
#              4243,
#             ...
#             49731, 49967, 50440, 51120, 51873, 52122, 52198, 52725, 52823,
#             52861],
#            dtype='int64', length=144), ('Tylenol with Codeine #3', 'Pain'): Int64Index([  141,  1717,  6414, 11651, 12053, 16554, 18368, 19456, 19945,
#             25377, 26470, 26890, 29365, 31437, 33399, 35888, 40400, 41600,
#             41611, 45648, 46214, 46395, 46665, 49610, 49948, 50872, 51469],
#            dtype='int64'), ('BuSpar', 'Panic Disorde'): Int64Index([142, 8368, 8662, 13917, 15712, 18588, 24994, 26593, 31857, 41778,
#             48612],
#            dtype='int64'), ('Magnesium citrate', 'Constipation'): Int64Index([  143,  1257,  2827,  4181,  5509,  6775,  7590,  9657, 12787,
#             13793, 14247, 14428, 15452, 19206, 19741, 20770, 21653, 26012,
#             27454, 28101, 28697, 28958, 29853, 30859, 32501, 32999, 33029,
#             33098, 33419, 33775, 34233, 38200, 39920, 41088, 41296, 42855,
#             43498, 46233, 46661, 46866, 47003, 51710, 52000, 52244, 53449],
#            dtype='int64'), ('Depo-Provera', 'Birth Control'): Int64Index([  145,   167,   196,   554,   791,   834,  1041,  1524,  1985,
#              2169,
#             ...
#             50662, 50690, 51347, 51517, 51831, 52082, 52249, 52292, 52593,
#             52964],
#            dtype='int64', length=154), ('Drospirenone / ethinyl estradiol', nan): Int64Index([146, 2366, 3278, 9757, 18365, 21295, 26757, 28274, 46543, 47524], dtype='int64'), ('Safyral', 'Birth Control'): Int64Index([147, 3510, 8290, 10811, 13257, 15592, 19156, 22669, 38123, 46351,
#             47644],
#            dtype='int64'), ('Desyrel', 'Insomnia'): Int64Index([150, 11009, 31784, 37833], dtype='int64'), ('Glyburide', 'Diabetes, Type 2'): Int64Index([151, 37035, 46097], dtype='int64'), ('Escitalopram', 'Generalized Anxiety Disorde'): Int64Index([  152,   866,  1279,  2519,  2576,  4350,  4394,  4773,  4832,
#              5192,
#             ...
#             50596, 51358, 51524, 52210, 52465, 52654, 52784, 53574, 53613,
#             53692],
#            dtype='int64', length=105), ('Aldesleukin', 'Renal Cell Carcinoma'): Int64Index([153], dtype='int64'), ('Zoloft', 'Social Anxiety Disorde'): Int64Index([  154,  1593,  1818,  3471,  3927,  7142,  8763, 10132, 11274,
#             12899, 13531, 13706, 13901, 14154, 14497, 14877, 15299, 19106,
#             19294, 19591, 19598, 21093, 23001, 23187, 23549, 23911, 24814,
#             28706, 30315, 31001, 31523, 31772, 31809, 31996, 32932, 33298,
#             34307, 38733, 39851, 41357, 42906, 43322, 45856, 46370, 46773,
#             46925, 52150],
#            dtype='int64'), ('Desvenlafaxine', 'Depression'): Int64Index([  155,   240,   405,   811,   939,  1502,  1604,  1615,  1678,
#              1723,
#             ...
#             51885, 51963, 52025, 52336, 52520, 52713, 53270, 53312, 53330,
#             53510],
#            dtype='int64', length=159), ('Levonorgestrel', nan): Int64Index([156, 2299, 15984, 31084, 40860, 46229, 50718, 52043], dtype='int64'), ('Drospirenone / ethinyl estradiol', 'Birth Control'): Int64Index([  157,   839,  1034,  1183,  1376,  1573,  1782,  2164,  2567,
#              3722,
#             ...
#             51369, 51487, 51978, 52046, 52544, 52595, 52776, 53044, 53212,
#             53231],
#            dtype='int64', length=163), ('Phentermine / topiramate', 'Obesity'): Int64Index([  158,  3134,  3238,  3963,  4179,  4218,  4979,  7095,  9241,
#             10119, 11278, 11785, 14606, 16615, 19804, 26347, 27391, 29794,
#             31005, 31277, 32748, 34116, 37005, 38098, 39345, 39702, 39793,
#             41399, 41946, 42323, 42495, 43195, 43954, 46005, 47125, 49374,
#             50133, 51178],
#            dtype='int64'), ('Pristiq', 'Major Depressive Disorde'): Int64Index([159, 1507, 6723, 20641, 31645, 34274, 34990, 39750, 49745], dtype='int64'), ('Acamprosate', 'Alcohol Dependence'): Int64Index([  162,  1554,  2910,  4004,  6241, 14229, 14365, 14897, 14990,
#             16447, 24079, 25787, 26914, 28803, 30061, 31036, 31225, 34143,
#             35825, 37523, 41465, 41880, 42203, 43360, 44038, 44746, 45570,
#             47255, 48175, 49490, 50003, 51350, 51859, 53271],
#            dtype='int64'), ('Spironolactone', 'Acne'): Int64Index([  163,   188,   320,   453,  2552,  2665,  3020,  3214,  4220,
#              7801,  8078,  8104,  8292,  9797, 10067, 10498, 10671, 12186,
#             12324, 12591, 13100, 13154, 13463, 14938, 14972, 17845, 19211,
#             19334, 19686, 20414, 23948, 24292, 24346, 24536, 24962, 25131,
#             25981, 27542, 28180, 28857, 29753, 30095, 30648, 31977, 33618,
#             33678, 33807, 34305, 36632, 40771, 40940, 44850, 45586, 46245,
#             47781, 49419, 50311, 50319, 52694, 52980],
#            dtype='int64'), ('Doxylamine / pyridoxine', 'Nausea/Vomiting of Pregnancy'): Int64Index([  164,  1304,  5782,  8048,  8376, 10752, 14493, 17079, 20425,
#             21175, 27692, 30491, 38682, 39040, 40012, 47158, 47467, 49219,
#             49665, 51026, 51419, 51853, 52416],
#            dtype='int64'), ('Demerol', 'Pain'): Int64Index([  165,  3235,  3570,  3780,  4706,  9301, 10137, 14251, 15725,
#             25002, 28021, 30350, 32536, 40760, 45190, 47923],
#            dtype='int64'), ('Vyvanse', 'Binge Eating Disorde'): Int64Index([  166,  1740,  3743,  6457, 11273, 16055, 16939, 24250, 25090,
#             30294, 33952, 37783, 39104, 42798, 47737],
#            dtype='int64'), ('Sovaldi', 'Hepatitis C'): Int64Index([168, 11492, 18937, 32025, 34325, 38773, 45854, 45882], dtype='int64'), ('Sertraline', 'Depression'): Int64Index([  169,   614,   688,  1306,  1458,  1879,  1922,  2019,  2078,
#              2084,
#             ...
#             49674, 51371, 51976, 52231, 52315, 52481, 52769, 53015, 53190,
#             53580],
#            dtype='int64', length=204), ('Motrin IB', 'Back Pain'): Int64Index([170], dtype='int64'), ('Valacyclovir', 'Cold Sores'): Int64Index([  171,  2880,  3938,  4767,  6528,  6956,  7289, 11944, 14297,
#             17320, 20658, 20776, 21691, 24278, 25048, 25270, 30227, 31425,
#             31674, 33108, 34202, 38825, 39082, 45487, 45799, 46328, 48571,
#             49997, 51153, 52167],
#            dtype='int64'), ('Buprenorphine / naloxone', 'Opiate Dependence'): Int64Index([  172,   615,   921,  1043,  1481,  1720,  2044,  2158,  2499,
#              2993,
#             ...
#             49534, 51218, 51405, 51804, 51899, 52034, 53035, 53363, 53545,
#             53560],
#            dtype='int64', length=164), ('Metoprolol', 'Heart Attack'): Int64Index([173], dtype='int64'), ('Pristiq', 'Depression'): Int64Index([  174,   825,  1175,  1176,  2675,  2746,  2928,  3169,  4146,
#              5116,
#             ...
#             49011, 50191, 50244, 50669, 52073, 52092, 52289, 53301, 53428,
#             53582],
#            dtype='int64', length=136), ('Montelukast', 'Asthma'): Int64Index([  175,  1117,  7205,  7386, 11471, 12725, 13963, 14311, 17953,
#             17960, 21568, 22982, 23176, 24813, 26982, 28396, 29250, 30330,
#             31061, 31235, 33891, 37479, 39180, 39356, 48292, 49461, 49713,
#             51809, 53441],
#            dtype='int64'), ('Dextromethorphan', 'Cough'): Int64Index([  176,   422,  3040,  3274,  3873,  6354,  7751,  9110,  9406,
#             10185, 11582, 12230, 15782, 15995, 17915, 19401, 19746, 20497,
#             21941, 25152, 26152, 29923, 31268, 31626, 32469, 33078, 35411,
#             36306, 36738, 38739, 40028, 40556, 41207, 43861, 44187, 45175,
#             46209, 47152, 47452, 49619, 50234, 50830, 51146, 51680, 51785,
#             51891, 51995, 52182, 53390],
#            dtype='int64'), ('Levitra', 'Erectile Dysfunction'): Int64Index([  177,  1962,  4014,  5401,  7455,  9587, 11605, 12133, 14885,
#             18820, 24267, 24496, 24781, 25714, 26981, 27801, 30304, 30692,
#             31198, 36646, 36985, 38126, 42199, 43516, 44139, 47256, 49527],
#            dtype='int64'), ('Restoril', 'Insomnia'): Int64Index([  178,  3932,  6158,  8480,  8748, 11794, 12713, 12938, 21137,
#             24758, 25381, 26272, 30156, 34726, 35175, 36627, 38309, 42645,
#             44250, 45543, 47060, 47728],
#            dtype='int64'), ('Azathioprine', 'Autoimmune Hepatitis'): Int64Index([179], dtype='int64'), ('Adapalene / benzoyl peroxide', 'Acne'): Int64Index([  180,   198,   633,  1380,  1428,  2219,  2480,  2700,  3147,
#              3972,
#             ...
#             50161, 50429, 51606, 51626, 52159, 52230, 52468, 52933, 53139,
#             53556],
#            dtype='int64', length=150), ('Linzess', 'Constipation, Chronic'): Int64Index([  181,  1324,  2295,  2333,  3301,  3411,  3753,  3909,  3998,
#              4483,  5174,  8206,  8370, 10165, 11349, 12286, 13401, 14985,
#             18792, 18874, 19323, 19477, 20961, 22331, 23809, 24576, 24601,
#             25443, 25607, 25937, 26885, 28001, 28654, 32482, 32521, 33377,
#             35613, 35913, 36790, 36957, 38888, 42675, 42820, 44857, 44858,
#             47927, 48164, 48194, 49764, 49995, 50047, 50667, 51490, 52727,
#             52971, 53145],
#            dtype='int64'), ('Levetiracetam', 'Seizures'): Int64Index([  182,   919,  1404,  3357,  6465,  8053,  8908, 11107, 11924,
#             12482, 15658, 15779, 16470, 17138, 17276, 17576, 17729, 19263,
#             24976, 30761, 31512, 31614, 33222, 37645, 37674, 38689, 39041,
#             40237, 40328, 47318, 47465, 48263, 49162, 50608, 51819],
#            dtype='int64'), ('Ziana', 'Acne'): Int64Index([  183,  3608,  4347,  5249,  6437,  6912,  8236, 20551, 21204,
#             22481, 22717, 32657, 36395, 47482, 47490, 49248, 51003, 52229,
#             53276],
#            dtype='int64'), ('Suboxone', 'Opiate Dependence'): Int64Index([  184,  1685,  2038,  2911,  3076,  3464,  3718,  4540,  5343,
#              6596,
#             ...
#             48156, 49208, 49822, 51229, 51393, 51510, 51732, 53022, 53047,
#             53151],
#            dtype='int64', length=119), ('Tinidazole', 'Bacterial Vaginitis'): Int64Index([186, 753, 9803, 24067, 25718, 27776, 31223, 32736], dtype='int64'), ('Diazepam', 'Not Listed / Othe'): Int64Index([187, 20549, 40813], dtype='int64'), ('Quetiapine', 'Bipolar Disorde'): Int64Index([  189,   548,   992,  2079,  2317,  2502,  2748,  3074,  3369,
#              3646,
#             ...
#             49354, 49390, 49570, 50917, 50954, 52563, 52642, 52752, 53034,
#             53323],
#            dtype='int64', length=102), ('Acetaminophen / butalbital / caffeine', 'Headache'): Int64Index([  190,   974,  1601,  2166,  3305,  4045,  4113,  5538,  5856,
#              6434,  6700,  8189,  9290, 11710, 15217, 15442, 17329, 17761,
#             18584, 19463, 19811, 20623, 21001, 21394, 22135, 24218, 24793,
#             25711, 25809, 27719, 28201, 28254, 30311, 30323, 32110, 32709,
#             32905, 40283, 43134, 43354, 43655, 45036, 45790, 46115, 48680,
#             50288, 51167, 51702, 53327],
#            dtype='int64'), ('Estradiol', 'Postmenopausal Symptoms'): Int64Index([  192,  1109,  1235,  1648,  1789,  4993,  6078,  7774,  7905,
#              9470,  9606, 12325, 13788, 14254, 19765, 20076, 20837, 21838,
#             23172, 24590, 29054, 29185, 30864, 30982, 34292, 38582, 42826,
#             43244, 45830, 46602, 47389, 47602, 49061, 49435, 50349, 51039,
#             52191, 52627, 53224, 53291],
#            dtype='int64'), ('Gabapentin', 'ibromyalgia'): Int64Index([  193,   966,  1540,  3242,  4591,  6008,  7113,  7381,  8909,
#              9844, 11902, 11922, 14176, 15616, 16652, 18601, 19171, 23060,
#             23395, 24858, 26722, 27908, 28655, 28999, 29428, 31116, 35422,
#             37495, 37691, 38441, 41628, 41646, 42441, 47101, 47238, 49202,
#             51638, 51851],
#            dtype='int64'), ('Propofol', 'Anesthesia'): Int64Index([  195,   550,   694,   873,   902,  1961,  2840,  5529,  5943,
#              7510,  8197,  8281,  9519,  9766, 12536, 14569, 14772, 15187,
#             15203, 17310, 17837, 18443, 19778, 21452, 22014, 22784, 24222,
#             24541, 25181, 25640, 27863, 28122, 28218, 28224, 28509, 30241,
#             31419, 31609, 31788, 32810, 33436, 34705, 34996, 35293, 35997,
# ...
#             22821, 23758, 24863, 25264, 27964, 29531, 32750, 39217, 43097,
#             44131, 44208, 46099, 50552, 52488, 52617],
#            dtype='int64'), ('Robaxin', 'Opiate Withdrawal'): Int64Index([16654], dtype='int64'), ('Vancomycin', 'Peritonitis'): Int64Index([16668], dtype='int64'), ('Terazosin', 'Benign Prostatic Hyperplasia'): Int64Index([16686, 24093, 25885, 46891], dtype='int64'), ('Flexeril', 'Migraine'): Int64Index([16695, 32172, 36031], dtype='int64'), ('Paclitaxel', 'Non-Small Cell Lung Cance'): Int64Index([16697], dtype='int64'), ('Requip XL', 'Periodic Limb Movement Disorde'): Int64Index([16701], dtype='int64'), ('Gonal-f', 'llicle Stimulation'): Int64Index([16703], dtype='int64'), ('Drospirenone / ethinyl estradiol / levomefolate calcium', 'Acne'): Int64Index([16708, 22850, 28100, 29272, 34530, 42459], dtype='int64'), ('Pennsaid', 'Osteoarthritis'): Int64Index([16732, 20344, 24323, 25203, 26954], dtype='int64'), ('Voltaren', 'Pain'): Int64Index([16735, 20963, 25139, 33150, 42168, 49113, 51672, 53102], dtype='int64'), ('Aubagio', 'Multiple Sclerosis'): Int64Index([16757, 22022, 29009, 34479, 43387], dtype='int64'), ('Desvenlafaxine', 'Narcolepsy'): Int64Index([16766], dtype='int64'), ('Polyethylene glycol 3350 with electrolytes', 'Constipation, Chronic'): Int64Index([16768, 23548, 49413], dtype='int64'), ('Diclofenac / misoprostol', 'Rheumatoid Arthritis'): Int64Index([16789, 19986], dtype='int64'), ('Albenza', 'Pinworm Infection (Enterobius vermicularis)'): Int64Index([16805], dtype='int64'), ('Levetiracetam', 'Not Listed / Othe'): Int64Index([16814], dtype='int64'), ('Insulin aspart / insulin degludec', 'Diabetes, Type 2'): Int64Index([16818], dtype='int64'), ('Lupron', 'Prostate Cance'): Int64Index([16823, 21972, 22549, 29766, 30840, 31312, 33628, 46138, 46916,
#             47915, 48863],
#            dtype='int64'), ('Famciclovir', 'Herpes Simplex, Mucocutaneous/Immunocompetent Host'): Int64Index([16826], dtype='int64'), ('Kenalog', 'Psoriasis'): Int64Index([16833, 41832], dtype='int64'), ('Zoloft', '9</span> users found this comment helpful.'): Int64Index([16834], dtype='int64'), ('Infliximab', 'Spondyloarthritis'): Int64Index([16859], dtype='int64'), ('Acetazolamide', 'Edema'): Int64Index([16873, 50099], dtype='int64'), ('Eplerenone', 'High Blood Pressure'): Int64Index([16896, 31340], dtype='int64'), ('Remicade', "Crohn's Disease"): Int64Index([16899], dtype='int64'), ('Vicoprofen', 'Pain'): Int64Index([16911, 18703, 20191, 25284, 28150, 30926, 31823, 42785, 51148], dtype='int64'), ('Oxytrol', 'Urinary Incontinence'): Int64Index([16927, 28876, 36626, 53097], dtype='int64'), ('Triamcinolone', 'Alopecia'): Int64Index([16954], dtype='int64'), ('Albiglutide', 'Diabetes, Type 2'): Int64Index([16960, 26109], dtype='int64'), ('Kariva', 'Polycystic Ovary Syndrome'): Int64Index([16969, 30378, 37470], dtype='int64'), ('Triamcinolone', 'Aphthous Ulce'): Int64Index([16973], dtype='int64'), ('Triamcinolone', 'Asthma'): Int64Index([16980], dtype='int64'), ('Triamcinolone', 'Pityriasis rubra pilaris'): Int64Index([16993], dtype='int64'), ('Nexavar', 'Hepatocellular Carcinoma'): Int64Index([17005], dtype='int64'), ('Ortho-Cept', 'Birth Control'): Int64Index([17028, 40950, 45121], dtype='int64'), ('Valproic acid', 'Epilepsy'): Int64Index([17041], dtype='int64'), ('Aspirin / carisoprodol', 'Muscle Spasm'): Int64Index([17043, 29395], dtype='int64'), ('Safyral', '3</span> users found this comment helpful.'): Int64Index([17066], dtype='int64'), ('Biaxin XL', 'Bronchitis'): Int64Index([17068], dtype='int64'), ('Keflex', 'Bladder Infection'): Int64Index([17074, 17840, 44723], dtype='int64'), ('Pamabrom', 'Edema'): Int64Index([17077], dtype='int64'), ('Hydroxyzine', 'Pruritus'): Int64Index([17084, 30990, 48516], dtype='int64'), ('Haloperidol', 'Psychosis'): Int64Index([17104, 42374, 48603, 48915, 48956, 51737], dtype='int64'), ('Aspirin / caffeine / orphenadrine', 'Muscle Spasm'): Int64Index([17105, 32270, 43748], dtype='int64'), ('Ryzolt', 'Pain'): Int64Index([17110, 53522], dtype='int64'), ('Tiotropium', 'Asthma, Maintenance'): Int64Index([17119], dtype='int64'), ('Jencycla', 'Birth Control'): Int64Index([17125, 20308], dtype='int64'), ('Xalkori', 'Non-Small Cell Lung Cance'): Int64Index([17137], dtype='int64'), ('Depo-Provera', 'Amenorrhea'): Int64Index([17140, 37647], dtype='int64'), ('Pamelor', 'Tinnitus'): Int64Index([17143], dtype='int64'), ('Dexamethasone / neomycin / polymyxin b', 'Conjunctivitis, Bacterial'): Int64Index([17151, 46693], dtype='int64'), ('Cleocin', 'Skin or Soft Tissue Infection'): Int64Index([17167], dtype='int64'), ('Loteprednol / tobramycin', 'Iritis'): Int64Index([17199], dtype='int64'), ('Eribulin', 'Breast Cancer, Metastatic'): Int64Index([17202, 29196], dtype='int64'), ('Spironolactone', 'Hirsutism'): Int64Index([17208, 20946, 39641, 39992, 40789], dtype='int64'), ('Equetro', 'Bipolar Disorde'): Int64Index([17214, 33040], dtype='int64'), ('Imatinib', 'Gastrointestinal Stromal Tum'): Int64Index([17233, 26266, 36856], dtype='int64'), ('Docusate / senna', 'Constipation, Acute'): Int64Index([17268, 18006, 35171, 38933, 47230], dtype='int64'), ('Asenapine', 'Borderline Personality Disorde'): Int64Index([17269], dtype='int64'), ('Coartem', 'Malaria'): Int64Index([17274], dtype='int64'), ('Evista', 'Prevention of Osteoporosis'): Int64Index([17275], dtype='int64'), ('Ibandronate', 'Osteoporosis'): Int64Index([17281, 20520, 26010, 30290], dtype='int64'), ('Diltiazem', 'Atrial Flutte'): Int64Index([17292, 21454], dtype='int64'), ('Prazosin', 'Benign Prostatic Hyperplasia'): Int64Index([17307], dtype='int64'), ('Sumavel DosePro', 'Migraine'): Int64Index([17315, 30067, 30549, 30669, 31673, 32189, 32274, 32425, 44672,
#             50977, 52809],
#            dtype='int64'), ('Humira', 'Ulcerative Colitis'): Int64Index([17341, 35259], dtype='int64'), ('Follicle stimulating hormone', 'llicle Stimulation'): Int64Index([17343], dtype='int64'), ('Azithromycin', 'COPD, Acute'): Int64Index([17344], dtype='int64'), ('Nortriptyline', 'Tinnitus'): Int64Index([17350, 23158], dtype='int64'), ('FreshKote', 'Eye Redness'): Int64Index([17369], dtype='int64'), ('Heme iron polypeptide', 'Iron Deficiency Anemia'): Int64Index([17404], dtype='int64'), ('Chlorpheniramine / dextromethorphan / pseudoephedrine', 'Cough and Nasal Congestion'): Int64Index([17408], dtype='int64'), ('Rivastigmine', "Parkinson's Disease"): Int64Index([17417], dtype='int64'), ('Econazole', 'Tinea Pedis'): Int64Index([17426], dtype='int64'), ('Itraconazole', 'Onychomycosis, Toenail'): Int64Index([17442, 41396], dtype='int64'), ('Desogestrel / ethinyl estradiol', 'Abnormal Uterine Bleeding'): Int64Index([17446], dtype='int64'), ('Cloderm', 'Dermatitis'): Int64Index([17451, 45285], dtype='int64'), ('Ipratropium', 'Rhinorrhea'): Int64Index([17463, 43899], dtype='int64'), ('Prednisone', 'Adrenocortical Insufficiency'): Int64Index([17467], dtype='int64'), ('Zyprexa', 'Insomnia'): Int64Index([17490, 26146, 37137], dtype='int64'), ('Movantik', 'Opioid-Induced Constipation'): Int64Index([17491, 18299, 22811, 32047, 38577, 41859], dtype='int64'), ('Budesonide', 'Asthma, Maintenance'): Int64Index([17502, 21896, 41154], dtype='int64'), ('Albendazole', 'Pinworm Infection (Enterobius vermicularis)'): Int64Index([17510], dtype='int64'), ('Doxepin', 'Urticaria'): Int64Index([17512, 40720], dtype='int64'), ('Betamethasone', 'Inflammatory Conditions'): Int64Index([17513], dtype='int64'), ('OnabotulinumtoxinA', 'acial Wrinkles'): Int64Index([17530, 18278], dtype='int64'), ('Carafate', 'Stomach Ulce'): Int64Index([17548], dtype='int64'), ('Pamine Forte', 'Irritable Bowel Syndrome'): Int64Index([17556, 30231, 43034], dtype='int64'), ('Entocort EC', "Crohn's Disease, Maintenance"): Int64Index([17564], dtype='int64'), ('Phenol', 'Sore Throat'): Int64Index([17578], dtype='int64'), ('Prochlorperazine', 'Anxiety'): Int64Index([17580, 19581, 25990], dtype='int64'), ('Loperamide', 'Diarrhea, Acute'): Int64Index([17593, 53532], dtype='int64'), ('Magnesium oxide', 'Hypomagnesemia'): Int64Index([17620], dtype='int64'), ('Erythromycin', 'Bronchitis'): Int64Index([17626], dtype='int64'), ('Promethazine', 'Allergic Reactions'): Int64Index([17643], dtype='int64'), ('Tramadol', 'Rheumatoid Arthritis'): Int64Index([17647], dtype='int64'), ('Megace', 'Endometrial Hyperplasia'): Int64Index([17653], dtype='int64'), ('Lactulose', 'Constipation, Chronic'): Int64Index([17656, 34506, 36734, 52687, 53262], dtype='int64'), ('Lithium', 'Borderline Personality Disorde'): Int64Index([17673, 47203], dtype='int64'), ('Polyethylene glycol 3350 with electrolytes', 'Gastrointestinal Decontamination'): Int64Index([17681, 25198], dtype='int64'), ('Promethazine', 'Light Sedation'): Int64Index([17685, 27265, 29966, 35823, 41432], dtype='int64'), ('Azilect', "Parkinson's Disease"): Int64Index([17689, 33328], dtype='int64'), ('Darvon', 'Pain'): Int64Index([17702, 22978], dtype='int64'), ('Sanctura XR', 'Overactive Bladde'): Int64Index([17725], dtype='int64'), ('Pegasys', 'Hepatitis C'): Int64Index([17731, 53339], dtype='int64'), ('Adenosine', 'Supraventricular Tachycardia'): Int64Index([17732, 45520], dtype='int64'), ('Lorazepam', 'Light Anesthesia'): Int64Index([17738, 22167], dtype='int64'), ('Cefdinir', 'Strep Throat'): Int64Index([17739, 35098, 41168, 49238], dtype='int64'), ('Metolazone', 'Edema'): Int64Index([17763, 29881], dtype='int64'), ('Privine', 'Nasal Congestion'): Int64Index([17769, 30432], dtype='int64'), ('Plecanatide', 'Chronic Idiopathic Constipation'): Int64Index([17777, 19599, 27889, 28730, 31572, 32890, 36375, 36750], dtype='int64'), ('R-Tanna', 'Cold Symptoms'): Int64Index([17780], dtype='int64'), ('Evamist', 'Postmenopausal Symptoms'): Int64Index([1780 ...
#             40460, 47399],
#            dtype='int64'), ('Lisdexamfetamine', 'Chronic Fatigue Syndrome'): Int64Index([19613, 34847], dtype='int64'), ('Calci-Chew', 'Osteoporosis'): Int64Index([19615], dtype='int64'), ('Belbuca', 'Pain'): Int64Index([19651], dtype='int64'), ('Valacyclovir', 'Varicella-Zoste'): Int64Index([19657], dtype='int64'), ('Etanercept', 'Psoriasis'): Int64Index([19658, 20699, 27382, 45092, 46157], dtype='int64'), ('Norpace', 'Arrhythmia'): Int64Index([19705], dtype='int64'), ('Crizotinib', 'Non-Small Cell Lung Cance'): Int64Index([19721], dtype='int64'), ('Infliximab', "Crohn's Disease, Maintenance"): Int64Index([19724, 42277, 51062], dtype='int64'), ('Methylphenidate', 'atigue'): Int64Index([19732, 29624, 52325], dtype='int64'), ('Warfarin', 'Deep Vein Thrombosis Prophylaxis after Hip Replacement Surgery'): Int64Index([19748], dtype='int64'), ('Thorazine', 'Schizophrenia'): Int64Index([19756], dtype='int64'), ('Lotemax', 'Cyclitis'): Int64Index([19757], dtype='int64'), ('Evzio', 'Reversal of Opioid Sedation'): Int64Index([19781], dtype='int64'), ('Emtricitabine / tenofovir', 'Pre-Exposure Prophylaxis'): Int64Index([19784], dtype='int64'), ('Rebif Rebidose', 'Multiple Sclerosis'): Int64Index([19790], dtype='int64'), ('Collagenase Santyl', 'Keratosis'): Int64Index([19798], dtype='int64'), ('Aldara', 'Human Papilloma Virus'): Int64Index([19824, 29687, 42451], dtype='int64'), ('Methylprednisolone', 'Neuralgia'): Int64Index([19826, 52127], dtype='int64'), ('Pyridium', 'Dysuria'): Int64Index([19832, 41346, 47116], dtype='int64'), ('Prednisolone', 'Iritis'): Int64Index([19858], dtype='int64'), ('Penicillin v potassium', 'Not Listed / Othe'): Int64Index([19859], dtype='int64'), ('Ceftriaxone', 'Urinary Tract Infection'): Int64Index([19862, 26244, 29821, 31728, 42291], dtype='int64'), ('Flecainide', 'Supraventricular Tachycardia'): Int64Index([19866], dtype='int64'), ('Warfarin', 'Deep Vein Thrombosis, First Event'): Int64Index([19876, 28673], dtype='int64'), ('Zyrtec-D', 'Allergic Rhinitis'): Int64Index([19882], dtype='int64'), ('Anacin', 'Pain'): Int64Index([19899, 30857], dtype='int64'), ('Falmina', 'Polycystic Ovary Syndrome'): Int64Index([19905], dtype='int64'), ('Zaroxolyn', 'Edema'): Int64Index([19910, 28652], dtype='int64'), ('Paroxetine', 'Major Depressive Disorde'): Int64Index([19924, 26441, 29849, 33999, 38937, 51910], dtype='int64'), ('GlipiZIDE XL', 'Diabetes, Type 2'): Int64Index([19966], dtype='int64'), ('Remeron', 'Hot Flashes'): Int64Index([19968], dtype='int64'), ('Linzess', '7</span> users found this comment helpful.'): Int64Index([19969], dtype='int64'), ('Dronedarone', 'Atrial Fibrillation'): Int64Index([19983], dtype='int64'), ('Dronabinol', 'Nausea/Vomiting, Chemotherapy Induced'): Int64Index([19997, 44159, 47562, 49028], dtype='int64'), ('Depakote', 'Mania'): Int64Index([20001, 48001, 49624], dtype='int64'), ('Vyvanse', 'Asperger Syndrome'): Int64Index([20005], dtype='int64'), ('ProAir RespiClick', 'Asthma, Maintenance'): Int64Index([20007], dtype='int64'), ('Cytomel', 'Underactive Thyroid'): Int64Index([20020, 48925], dtype='int64'), ('Loxapine', 'Agitation'): Int64Index([20036], dtype='int64'), ('Flurandrenolide', 'Psoriasis'): Int64Index([20041], dtype='int64'), ('Femara', 'emale Infertility'): Int64Index([20043], dtype='int64'), ('Derma-Smoothe / FS (Scalp)', 'Seborrheic Dermatitis'): Int64Index([20048], dtype='int64'), ('Gemfibrozil', 'High Cholesterol'): Int64Index([20058, 41019, 43262], dtype='int64'), ('Pristiq', 'ADHD'): Int64Index([20075], dtype='int64'), ('Flomax', '9</span> users found this comment helpful.'): Int64Index([20104], dtype='int64'), ('Invega Trinza', 'Schizophrenia'): Int64Index([20121, 28647, 52924], dtype='int64'), ('Clarinex', 'Urticaria'): Int64Index([20122], dtype='int64'), ('Esomeprazole', "Barrett's Esophagus"): Int64Index([20129], dtype='int64'), ('Keflex', 'Skin or Soft Tissue Infection'): Int64Index([20132, 20385, 21044, 22961, 23162, 38420, 48285], dtype='int64'), ('Emtricitabine / ...
# Int64Index([    0,   366,   742,  1996,  2172,  2225,  2251,  2992,  3108,
#              3484,  3801,  4435,  5866,  8729, 10227, 12629, 13446, 13510,
#             14389, 16971, 17136, 17376, 18532, 18783, 19221, 19450, 19972,
#             21095, 21363, 22305, 22548, 24334, 24674, 25596, 25821, 27080,
#             27733, 28124, 30515, 31937, 32154, 32318, 32579, 34052, 34178,
#             35445, 36250, 36528, 38025, 38330, 38784, 40808, 40909, 41758,
#             41884, 41937, 42899, 44134, 44985, 45106, 45518, 45839, 46047,
#             46123, 47106, 47476, 47717, 47932, 48877, 48969, 49308, 50020,
#             50726, 52932, 53221],
#            dtype='int64')

# %%
rating_mean = df.groupby(['drugName'])['rating'].mean()
rating_mean.head(15)
# Out:
# drugName
# A / B Otic                              10.000000
# Abacavir / dolutegravir / lamivudine     9.000000
# Abacavir / lamivudine                   10.000000
# Abatacept                                6.500000
# Abilify                                  6.149660
# Abilify Discmelt                         9.000000
# Abilify Maintena                        10.000000
# Abiraterone                              9.666667
# AbobotulinumtoxinA                      10.000000
# Abreva                                   6.446809
# Absorica                                 6.500000
# Abstral                                  4.000000
# Acamprosate                              8.764706
# Acanya                                   7.000000
# Acarbose                                 8.000000
# Name: rating, dtype: float64

# %%
rating_stddev = df.groupby('drugName')['rating'].std()
rating_stddev.head(15)
# Out:
# drugName
# A / B Otic                                   NaN
# Abacavir / dolutegravir / lamivudine    2.169305
# Abacavir / lamivudine                   0.000000
# Abatacept                               3.209361
# Abilify                                 3.521662
# Abilify Discmelt                             NaN
# Abilify Maintena                             NaN
# Abiraterone                             0.577350
# AbobotulinumtoxinA                           NaN
# Abreva                                  3.871908
# Absorica                                3.535534
# Abstral                                      NaN
# Acamprosate                             2.000891
# Acanya                                  3.431877
# Acarbose                                     NaN
# Name: rating, dtype: float64

# %%
# pivotdf = pd.pivot_table(df,index=["drugName"],
#               values=["rating"],
#               aggfunc=[np.mean, confidence_interval])

# %% [markdown]
# [obtaining a confidence interval](https://stackoverflow.com/questions/28242593/correct-way-to-obtain-confidence-interval-with-scipy)
