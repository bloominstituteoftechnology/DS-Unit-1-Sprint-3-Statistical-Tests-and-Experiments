# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnMorrisonn/DS-Unit-1-Sprint-3-Statistical-Tests-and-Experiments/blob/master/131_Statistics_Probability_Assignment_John_Morrison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 1 Sprint 3 Assignment 1*
#
# # Apply the t-test to real data
#
# Your assignment is to determine which issues have "statistically significant" differences between political parties in this [1980s congressional voting data](https://archive.ics.uci.edu/ml/datasets/Congressional+Voting+Records). The data consists of 435 instances (one for each congressperson), a class (democrat or republican), and 16 binary attributes (yes or no for voting for or against certain issues). Be aware - there are missing values!
#
# Your goals:
#
# 1. Load and clean the data (or determine the best method to drop observations when running tests)
# 2. Using hypothesis testing, find an issue that democrats support more than republicans with p < 0.01
# 3. Using hypothesis testing, find an issue that republicans support more than democrats with p < 0.01
# 4. Using hypothesis testing, find an issue where the difference between republicans and democrats has p > 0.1 (i.e. there may not be much of a difference)
#
# Note that this data will involve *2 sample* t-tests, because you're comparing averages across two groups (republicans and democrats) rather than a single group against a null hypothesis.
#
# Stretch goals:
#
# 1. Refactor your code into functions so it's easy to rerun with arbitrary variables
# 2. Apply hypothesis testing to your personal project data (for the purposes of this notebook you can type a summary of the hypothesis you formed and tested)

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_1samp, ttest_ind, ttest_ind_from_stats, ttest_rel
import seaborn as sns

# %%
columns = [
    'party', 'hcapped-infants',
    'water-project', 'budget-resolution',
    'phys-fee-freeze', 'el-salvador-aid',
    'relig-groups', 'anti-satellite',
    'aid-to-nic', 'mx-missile',
    'immigration','synfuels-cutback',
    'edu-spending', 'superfund-sue',
    'crime', 'duty-exports',
    'export-africa'
]

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/voting-records/house-votes-84.data', names=columns)
df.head()
# Out:
#         party hcapped-infants water-project  ... crime duty-exports export-africa
# 0  republican               n             y  ...     y            n             y
# 1  republican               n             y  ...     y            n             ?
# 2    democrat               ?             y  ...     y            n             n
# 3    democrat               n             y  ...     n            n             y
# 4    democrat               y             y  ...     y            y             y
#
# [5 rows x 17 columns]

# %%
df = df.replace({'n': int(0), 'y': int(1), '?': None})

# %%
df.head()
# Out:
#         party  hcapped-infants  ...  duty-exports  export-africa
# 0  republican              0.0  ...           0.0            1.0
# 1  republican              0.0  ...           0.0            NaN
# 2    democrat              NaN  ...           0.0            0.0
# 3    democrat              0.0  ...           0.0            1.0
# 4    democrat              1.0  ...           1.0            1.0
#
# [5 rows x 17 columns]

# %%
#Creating the parties
rep = df[df['party'] == 'republican']
dem = df[df['party'] == 'democrat']
rep
# Out:
#           party  hcapped-infants  ...  duty-exports  export-africa
# 0    republican              0.0  ...           0.0            1.0
# 1    republican              0.0  ...           0.0            NaN
# 7    republican              0.0  ...           NaN            1.0
# 8    republican              0.0  ...           0.0            1.0
# 10   republican              0.0  ...           0.0            0.0
# 11   republican              0.0  ...           NaN            NaN
# 14   republican              0.0  ...           0.0            NaN
# 15   republican              0.0  ...           0.0            NaN
# 18   republican              0.0  ...           0.0            0.0
# 28   republican              1.0  ...           0.0            1.0
# 30   republican              0.0  ...           0.0            0.0
# 33   republican              0.0  ...           0.0            1.0
# 35   republican              0.0  ...           0.0            0.0
# 36   republican              1.0  ...           0.0            1.0
# 37   republican              1.0  ...           0.0            1.0
# 38   republican              0.0  ...           0.0            0.0
# 49   republican              0.0  ...           0.0            0.0
# 51   republican              0.0  ...           0.0            1.0
# 53   republican              1.0  ...           0.0            0.0
# 55   republican              0.0  ...           0.0            0.0
# 56   republican              0.0  ...           0.0            1.0
# 57   republican              0.0  ...           0.0            1.0
# 58   republican              0.0  ...           0.0            1.0
# 59   republican              0.0  ...           0.0            NaN
# 61   republican              0.0  ...           0.0            0.0
# 65   republican              1.0  ...           0.0            1.0
# 66   republican              0.0  ...           0.0            1.0
# 67   republican              0.0  ...           0.0            0.0
# 71   republican              1.0  ...           0.0            1.0
# 73   republican              1.0  ...           0.0            1.0
# ..          ...              ...  ...           ...            ...
# 356  republican              0.0  ...           0.0            0.0
# 357  republican              0.0  ...           0.0            0.0
# 359  republican              0.0  ...           0.0            1.0
# 363  republican              1.0  ...           0.0            0.0
# 364  republican              1.0  ...           0.0            1.0
# 369  republican              0.0  ...           0.0            1.0
# 374  republican              0.0  ...           0.0            1.0
# 377  republican              0.0  ...           NaN            NaN
# 378  republican              0.0  ...           0.0            1.0
# 379  republican              0.0  ...           0.0            1.0
# 392  republican              1.0  ...           0.0            1.0
# 393  republican              NaN  ...           0.0            NaN
# 399  republican              0.0  ...           0.0            0.0
# 400  republican              0.0  ...           0.0            NaN
# 401  republican              0.0  ...           0.0            0.0
# 402  republican              NaN  ...           0.0            1.0
# 403  republican              0.0  ...           0.0            0.0
# 404  republican              1.0  ...           0.0            1.0
# 405  republican              0.0  ...           0.0            1.0
# 409  republican              0.0  ...           0.0            0.0
# 410  republican              0.0  ...           0.0            1.0
# 412  republican              0.0  ...           0.0            1.0
# 413  republican              1.0  ...           0.0            1.0
# 416  republican              1.0  ...           0.0            1.0
# 420  republican              1.0  ...           0.0            1.0
# 427  republican              0.0  ...           0.0            1.0
# 430  republican              0.0  ...           0.0            1.0
# 432  republican              0.0  ...           0.0            1.0
# 433  republican              0.0  ...           0.0            1.0
# 434  republican              0.0  ...           NaN            0.0
#
# [168 rows x 17 columns]

# %% [markdown]
# Handicapped-Infants (Dems support more)

# %%
print("Democrat Support: ", dem['hcapped-infants'].mean())
print("Republican Support: ", rep['hcapped-infants'].mean())
ttest_ind(rep['hcapped-infants'], dem['hcapped-infants'], nan_policy='omit')
# Out:
# Democrat Support:  0.6046511627906976
# Republican Support:  0.18787878787878787
# Ttest_indResult(statistic=-9.205264294809222, pvalue=1.613440327937243e-18)

# %% [markdown]
# 1. Null Hypothesis: Any member is predicted to vote either way on this topic regardless of party.
#
# 2. Alternative Hypothesis: Party association will affect the voting behavior of this topic.
#
# 3. pvalue=1.613440327937243e-18 < 0.05 --> Reject the null hypothesis
#
# 4. T-stat = -9.20
#
# 5. p:value = 1.613440327937243e-18
#
# Interpretation: Due to calculating the t-statistic -9.20 and p-value 1.6e-18, we reject the null hypothesis that party relation has no affect on voting with this policy and suggest the alternative hypothesis.

# %% [markdown]
# Physician Fee Freeze (Republicans Support More)

# %%
print("Democrat Support: ", dem['phys-fee-freeze'].mean())
print("Republican Support: ", rep['phys-fee-freeze'].mean())
ttest_ind(rep['phys-fee-freeze'], dem['phys-fee-freeze'], nan_policy='omit')
# Out:
# Democrat Support:  0.05405405405405406
# Republican Support:  0.9878787878787879
# Ttest_indResult(statistic=49.36708157301406, pvalue=1.994262314074344e-177)

# %% [markdown]
# 1. Null Hypothesis: Any member is predicted to vote either way on this topic regardless of party.
#
# 2. Alternative Hypothesis: Party association will affect the voting behavior of this topic.
#
# 3. pvalue=1.994262314074344e-177< 0.05 --> Reject the null hypothesis
#
# 4. T-stat = 49.36
#
# 5. p:value = 1.994262314074344e-177
#
# Interpretation: Due to calculating the t-statistic 49.36 and p-value 1.99e-177, we reject the null hypothesis that party relation has no affect on voting with this policy and suggest the alternative hypothesis.

# %% [markdown]
# Water Project Cost Sharing (Little Party Difference)

# %%
print("Democrat Support: ", dem['water-project'].mean())
print("Republican Support: ", rep['water-project'].mean())
ttest_ind(rep['water-project'], dem['water-project'], nan_policy='omit')
# Out:
# Democrat Support:  0.502092050209205
# Republican Support:  0.5067567567567568
# Ttest_indResult(statistic=0.08896538137868286, pvalue=0.9291556823993485)

# %% [markdown]
# 1. Null Hypothesis: Any member is predicted to vote either way on this topic regardless of party.
#
# 2. Alternative Hypothesis: Party association will affect the voting behavior of this topic.
#
# 3. pvalue=0.929 --> Fail to reject the null hypothesis
#
# 4. T-stat = 0.089
#
# 5. p:value = 0.929
#
# Interpretation: Due to calculating the t-statistic 0.089 and p-value 0.929, we fail to reject the null hypothesis that party relation has no affect on voting with this policy.

# %%
def two_sample_t(array1, array2):
  return ttest_ind(array1, array2, nan_policy='omit')

def one_sample_t(array1, null):
  return ttest_1samp(array1, null, nan_policy='omit')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ed3c0cbe-21b6-48d1-94c0-d845c0986e0c" name="files[]" multiple disabled />
#      <output id="result-ed3c0cbe-21b6-48d1-94c0-d845c0986e0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving New Africa.csv to New Africa.csv

# %%
africa_df = pd.read_csv('New Africa.csv')
africa_df.head()
# Out:
#    Unnamed: 0  case  country  ...  lifespan  population                    region
# 0           0     1  Algeria  ...     22.00     3811028  middle_east_north_africa
# 1           1     1  Algeria  ...     28.86     3841635  middle_east_north_africa
# 2           2     1  Algeria  ...     28.90     3872845  middle_east_north_africa
# 3           3     1  Algeria  ...     28.94     3902099  middle_east_north_africa
# 4           4     1  Algeria  ...     28.98     3934634  middle_east_north_africa
#
# [5 rows x 18 columns]

# %%
Algeria = africa_df[africa_df['country'] == 'Algeria']
Zimbabwe = africa_df[africa_df['country'] == 'Zimbabwe']

# %%
print(Algeria.shape)
Algeria.head()
# Out:
# (85, 18)
#    Unnamed: 0  case  country  ...  lifespan  population                    region
# 0           0     1  Algeria  ...     22.00     3811028  middle_east_north_africa
# 1           1     1  Algeria  ...     28.86     3841635  middle_east_north_africa
# 2           2     1  Algeria  ...     28.90     3872845  middle_east_north_africa
# 3           3     1  Algeria  ...     28.94     3902099  middle_east_north_africa
# 4           4     1  Algeria  ...     28.98     3934634  middle_east_north_africa
#
# [5 rows x 18 columns]

# %%
print(Zimbabwe.shape)
Zimbabwe.head()
# Out:
# (90, 18)
#      Unnamed: 0  case   country  ...  lifespan  population              region
# 969         969    70  Zimbabwe  ...     34.54     2215961  sub_saharan_africa
# 970         970    70  Zimbabwe  ...     34.56     2231838  sub_saharan_africa
# 971         971    70  Zimbabwe  ...     34.57     2247829  sub_saharan_africa
# 972         972    70  Zimbabwe  ...     34.64     2312948  sub_saharan_africa
# 973         973    70  Zimbabwe  ...     34.65     2329520  sub_saharan_africa
#
# [5 rows x 18 columns]

# %%
two_sample_t(Algeria['lifespan'], Zimbabwe['lifespan'])
# Out:
# Ttest_indResult(statistic=2.472526131799752, pvalue=0.014382632427037146)

# %% [markdown]
# Hypothesis: The average lifespan of two countries in Africa differ significantly over time  *How can I make this better???*
#
# Null Hypothesis: The two countries' average lifespans do not differ significantly
#
# Alternative Hypothesis: The two countries' average lifespans differ significantly
#
# 95% : p-value 0.0143 < 0.05 --> Reject the null hypothesis
#
# T-stat = 2.47
#
# p-value = 0.014
#
# Due to the t-stat of 2.47 and p-value of 0.0143, we reject the null hypothesis that the average lifespans of these two countries are the same. However, the considerable high p-value should still note caution when inferring this rejection of the null.
